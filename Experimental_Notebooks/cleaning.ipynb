# %%
import pandas as pd
import numpy as np
import subject_data
from sklearn.model_selection import train_test_split
from datetime import datetime, timedelta
# Out:
# 100%|██████████| 226/226 [00:24<00:00,  9.28it/s]

# %%
cgm = subject_data.df_CGM
cgm['time'] = pd.to_datetime(cgm['time'])

def get_corresponding_day(date_time):
        if date_time.hour < 6:  # If before 6 AM, it belongs to the previous day
            return date_time.date() - timedelta(days=1)
        else:
            return date_time.date()

cgm['corresponding_day'] = cgm['time'].apply(get_corresponding_day)

unique_ids = cgm['id'].unique()
# Split the unique IDs into training, validation and test sets 80:10:10
train_ids, test_ids = train_test_split(unique_ids, test_size=0.1, random_state=42)
train_ids, validation_ids = train_test_split(train_ids, test_size=0.111, random_state=42)
# Create the training and test DataFrames based on the split IDs
train_data = cgm[cgm['id'].isin(train_ids)]
validation_data = cgm[cgm['id'].isin(train_ids)]
test_data = cgm[cgm['id'].isin(test_ids)]

# %%
def filter_valid_days(group):
    day_values = group[(group['time'].dt.hour >= 6) & (group['time'].dt.hour < 24)]
    filtered_on_day = day_values[day_values.groupby(['corresponding_day']).transform('size') >= 208]
    final_hour_values = filtered_on_day[filtered_on_day['time'].dt.hour >= 23]
    final_hour_values = final_hour_values[final_hour_values['time'].dt.hour < 24]
    filtered_on_final_hour = final_hour_values[final_hour_values.groupby(['corresponding_day']).transform('size') >= 11]
    filtered_days = filtered_on_final_hour['corresponding_day'].unique()
    filtered_group = group[group['corresponding_day'].isin(filtered_days)]
    return filtered_group

# %%
cgm = cgm.groupby('id').apply(filter_valid_days)

# %%
day = cgm[(cgm['time'].dt.hour >= 6) & (cgm['time'].dt.hour < 24)].rename(columns={'id': 'patient_id'})
night = cgm[(cgm['time'].dt.hour >= 0) & (cgm['time'].dt.hour < 6)].rename(columns={'id': 'patient_id'})

# %%
night.reset_index(inplace=True)
night_hypo = night.groupby(['id', 'corresponding_day']).agg({'bgl': lambda x: (x < 70).mean() > 0.04}).rename(columns={'bgl': 'hypo'}).reset_index()

# %%
print(len(day['corresponding_day'].unique()))
print(len(night['corresponding_day'].unique()))
print(len(cgm['corresponding_day'].unique()))
# Out:
# 501
# 501
# 501

# %%
# Ensure 'time' is a datetime type and set it as the index
day['time'] = pd.to_datetime(day['time'])
day.set_index('time', inplace=True)

# Resample every 5 minutes and calculate mean, std, and count for 'bgl'
resampled_day = day.groupby(['patient_id', 'corresponding_day']).resample('5T').agg({
    'bgl': ['mean']
}).reset_index()

# Flatten the MultiIndex columns if needed
resampled_day.columns = ['patient_id', 'corresponding_day', 'time', 'mean_bgl']

# Set 'time' back as a column if needed
resampled_day.set_index('time', inplace=True)

# Interpolate 'mean_bgl' for each patient group
for patient_id, group in resampled_day.groupby(['patient_id', 'corresponding_day']):
    print(f'id {patient_id}')
    resampled_day.loc[group.index, 'mean_bgl'] = group['mean_bgl'].interpolate(limit=10, limit_direction='both', method='linear')
# Out:
# id (2, datetime.date(2015, 5, 23))
# id (2, datetime.date(2015, 5, 24))
# id (2, datetime.date(2015, 5, 25))
# id (2, datetime.date(2015, 5, 26))
# id (2, datetime.date(2015, 5, 27))
# id (2, datetime.date(2015, 5, 28))
# id (2, datetime.date(2015, 5, 30))
# id (2, datetime.date(2015, 5, 31))
# id (2, datetime.date(2015, 6, 1))
# id (2, datetime.date(2015, 6, 2))
# id (2, datetime.date(2015, 6, 3))
# id (2, datetime.date(2015, 6, 4))
# id (2, datetime.date(2015, 6, 6))
# id (2, datetime.date(2015, 6, 7))
# id (2, datetime.date(2015, 6, 8))
# id (2, datetime.date(2015, 6, 9))
# id (2, datetime.date(2015, 6, 11))
# id (2, datetime.date(2015, 6, 12))
# id (2, datetime.date(2015, 6, 13))
# id (2, datetime.date(2015, 6, 14))
# id (2, datetime.date(2015, 6, 15))
# id (2, datetime.date(2015, 6, 16))
# id (2, datetime.date(2015, 6, 18))
# id (2, datetime.date(2015, 6, 19))
# id (2, datetime.date(2015, 6, 20))
# id (2, datetime.date(2015, 6, 21))
# id (2, datetime.date(2015, 6, 22))
# id (2, datetime.date(2015, 6, 23))
# id (2, datetime.date(2015, 6, 25))
# id (2, datetime.date(2015, 6, 26))
# id (2, datetime.date(2015, 6, 27))
# id (2, datetime.date(2015, 6, 28))
# id (2, datetime.date(2015, 6, 29))
# id (2, datetime.date(2015, 6, 30))
# id (2, datetime.date(2015, 7, 2))
# id (2, datetime.date(2015, 7, 3))
# id (2, datetime.date(2015, 7, 5))
# id (2, datetime.date(2015, 7, 6))
# id (2, datetime.date(2015, 7, 7))
# id (2, datetime.date(2015, 7, 8))
# id (2, datetime.date(2015, 7, 9))
# id (2, datetime.date(2015, 7, 10))
# id (2, datetime.date(2015, 7, 12))
# id (2, datetime.date(2015, 7, 13))
# id (2, datetime.date(2015, 7, 14))
# id (2, datetime.date(2015, 7, 16))
# id (2, datetime.date(2015, 7, 17))
# id (2, datetime.date(2015, 7, 18))
# id (2, datetime.date(2015, 7, 19))
# id (2, datetime.date(2015, 7, 20))
# id (2, datetime.date(2015, 7, 21))
# id (2, datetime.date(2015, 7, 23))
# id (2, datetime.date(2015, 7, 24))
# id (2, datetime.date(2015, 7, 26))
# id (2, datetime.date(2015, 7, 28))
# id (2, datetime.date(2015, 7, 29))
# id (2, datetime.date(2015, 7, 30))
# id (2, datetime.date(2015, 7, 31))
# id (2, datetime.date(2015, 8, 2))
# id (2, datetime.date(2015, 8, 3))
# id (2, datetime.date(2015, 8, 4))
# id (2, datetime.date(2015, 8, 5))
# id (2, datetime.date(2015, 8, 6))
# id (2, datetime.date(2015, 8, 7))
# id (2, datetime.date(2015, 8, 9))
# id (2, datetime.date(2015, 8, 10))
# id (2, datetime.date(2015, 8, 11))
# id (2, datetime.date(2015, 8, 12))
# id (2, datetime.date(2015, 8, 13))
# id (2, datetime.date(2015, 8, 14))
# id (2, datetime.date(2015, 8, 16))
# id (2, datetime.date(2015, 8, 17))
# id (2, datetime.date(2015, 8, 18))
# id (2, datetime.date(2015, 8, 19))
# id (2, datetime.date(2015, 8, 20))
# id (2, datetime.date(2015, 8, 21))
# id (2, datetime.date(2015, 8, 23))
# id (2, datetime.date(2015, 8, 24))
# id (2, datetime.date(2015, 8, 25))
# id (2, datetime.date(2015, 8, 26))
# id (2, datetime.date(2015, 8, 27))
# id (2, datetime.date(2015, 8, 28))
# id (2, datetime.date(2015, 8, 30))
# id (2, datetime.date(2015, 8, 31))
# id (2, datetime.date(2015, 9, 1))
# id (2, datetime.date(2015, 9, 2))
# id (2, datetime.date(2015, 9, 3))
# id (2, datetime.date(2015, 9, 4))
# id (2, datetime.date(2015, 9, 6))
# id (2, datetime.date(2015, 9, 7))
# id (2, datetime.date(2015, 9, 8))
# id (2, datetime.date(2015, 9, 9))
# id (2, datetime.date(2015, 9, 10))
# id (2, datetime.date(2015, 9, 11))
# id (2, datetime.date(2015, 9, 14))
# id (2, datetime.date(2015, 9, 15))
# id (2, datetime.date(2015, 9, 16))
# id (2, datetime.date(2015, 9, 17))
# id (2, datetime.date(2015, 9, 18))
# id (2, datetime.date(2015, 9, 20))
# id (2, datetime.date(2015, 9, 22))
# id (2, datetime.date(2015, 9, 23))
# id (2, datetime.date(2015, 9, 24))
# id (2, datetime.date(2015, 9, 25))
# id (2, datetime.date(2015, 9, 27))
# id (2, datetime.date(2015, 9, 28))
# id (2, datetime.date(2015, 9, 29))
# id (2, datetime.date(2015, 9, 30))
# id (2, datetime.date(2015, 10, 1))
# id (2, datetime.date(2015, 10, 2))
# id (2, datetime.date(2015, 10, 4))
# id (2, datetime.date(2015, 10, 6))
# id (2, datetime.date(2015, 10, 7))
# id (2, datetime.date(2015, 10, 8))
# id (2, datetime.date(2015, 10, 9))
# id (2, datetime.date(2015, 10, 10))
# id (2, datetime.date(2015, 10, 11))
# id (2, datetime.date(2015, 10, 13))
# id (2, datetime.date(2015, 10, 14))
# id (2, datetime.date(2015, 10, 15))
# id (2, datetime.date(2015, 10, 16))
# id (2, datetime.date(2015, 10, 18))
# id (2, datetime.date(2015, 10, 21))
# id (2, datetime.date(2015, 10, 23))
# id (2, datetime.date(2015, 10, 24))
# id (2, datetime.date(2015, 10, 25))
# id (2, datetime.date(2015, 10, 26))
# id (2, datetime.date(2015, 10, 27))
# id (2, datetime.date(2015, 10, 28))
# id (2, datetime.date(2015, 10, 30))
# id (2, datetime.date(2015, 10, 31))
# id (2, datetime.date(2015, 11, 1))
# id (2, datetime.date(2015, 11, 2))
# id (2, datetime.date(2015, 11, 3))
# id (2, datetime.date(2015, 11, 4))
# id (2, datetime.date(2015, 11, 6))
# id (2, datetime.date(2015, 11, 7))
# id (2, datetime.date(2015, 11, 8))
# id (2, datetime.date(2015, 11, 9))
# id (2, datetime.date(2015, 11, 10))
# id (2, datetime.date(2015, 11, 11))
# id (2, datetime.date(2015, 11, 13))
# id (2, datetime.date(2015, 11, 15))
# id (2, datetime.date(2015, 11, 16))
# id (2, datetime.date(2015, 11, 17))
# id (2, datetime.date(2015, 11, 18))
# id (2, datetime.date(2015, 11, 19))
# id (2, datetime.date(2015, 11, 20))
# id (2, datetime.date(2015, 11, 23))
# id (2, datetime.date(2015, 11, 24))
# id (2, datetime.date(2015, 11, 25))
# id (2, datetime.date(2015, 11, 26))
# id (2, datetime.date(2015, 11, 27))
# id (2, datetime.date(2015, 11, 29))
# id (2, datetime.date(2015, 11, 30))
# id (2, datetime.date(2015, 12, 1))
# id (2, datetime.date(2015, 12, 2))
# id (2, datetime.date(2015, 12, 3))
# id (2, datetime.date(2015, 12, 4))
# id (2, datetime.date(2015, 12, 7))
# id (2, datetime.date(2015, 12, 8))
# id (2, datetime.date(2015, 12, 9))
# id (2, datetime.date(2015, 12, 10))
# id (2, datetime.date(2015, 12, 11))
# id (2, datetime.date(2015, 12, 13))
# id (2, datetime.date(2015, 12, 14))
# id (2, datetime.date(2015, 12, 15))
# id (2, datetime.date(2015, 12, 16))
# id (2, datetime.date(2015, 12, 17))
# id (2, datetime.date(2015, 12, 18))
# id (2, datetime.date(2015, 12, 20))
# id (2, datetime.date(2015, 12, 21))
# id (2, datetime.date(2015, 12, 23))
# id (2, datetime.date(2015, 12, 24))
# id (2, datetime.date(2015, 12, 25))
# id (2, datetime.date(2015, 12, 27))
# id (2, datetime.date(2015, 12, 28))
# id (2, datetime.date(2015, 12, 29))
# id (2, datetime.date(2015, 12, 30))
# id (2, datetime.date(2016, 1, 2))
# id (2, datetime.date(2016, 1, 4))
# id (2, datetime.date(2016, 1, 5))
# id (2, datetime.date(2016, 1, 6))
# id (2, datetime.date(2016, 1, 7))
# id (2, datetime.date(2016, 1, 9))
# id (2, datetime.date(2016, 1, 10))
# id (2, datetime.date(2016, 1, 11))
# id (2, datetime.date(2016, 1, 12))
# id (2, datetime.date(2016, 1, 13))
# id (2, datetime.date(2016, 1, 14))
# id (2, datetime.date(2016, 1, 16))
# id (2, datetime.date(2016, 1, 17))
# id (2, datetime.date(2016, 1, 18))
# id (3, datetime.date(2015, 5, 23))
# id (3, datetime.date(2015, 5, 24))
# id (3, datetime.date(2015, 5, 25))
# id (3, datetime.date(2015, 5, 26))
# id (3, datetime.date(2015, 5, 27))
# id (3, datetime.date(2015, 5, 29))
# id (3, datetime.date(2015, 5, 30))
# id (3, datetime.date(2015, 5, 31))
# id (3, datetime.date(2015, 6, 1))
# id (3, datetime.date(2015, 6, 2))
# id (3, datetime.date(2015, 6, 3))
# id (3, datetime.date(2015, 6, 5))
# id (3, datetime.date(2015, 6, 6))
# id (3, datetime.date(2015, 6, 8))
# id (3, datetime.date(2015, 6, 9))
# id (3, datetime.date(2015, 6, 10))
# id (3, datetime.date(2015, 6, 12))
# id (3, datetime.date(2015, 6, 13))
# id (3, datetime.date(2015, 6, 14))
# id (3, datetime.date(2015, 6, 15))
# id (3, datetime.date(2015, 6, 16))
# id (3, datetime.date(2015, 6, 17))
# id (3, datetime.date(2015, 6, 19))
# id (3, datetime.date(2015, 6, 20))
# id (3, datetime.date(2015, 6, 21))
# id (3, datetime.date(2015, 6, 22))
# id (3, datetime.date(2015, 6, 23))
# id (3, datetime.date(2015, 6, 24))
# id (3, datetime.date(2015, 6, 26))
# id (3, datetime.date(2015, 6, 27))
# id (3, datetime.date(2015, 6, 28))
# id (3, datetime.date(2015, 6, 29))
# id (3, datetime.date(2015, 7, 1))
# id (3, datetime.date(2015, 7, 2))
# id (3, datetime.date(2015, 7, 3))
# id (3, datetime.date(2015, 7, 4))
# id (3, datetime.date(2015, 7, 5))
# id (3, datetime.date(2015, 7, 7))
# id (3, datetime.date(2015, 7, 8))
# id (3, datetime.date(2015, 7, 9))
# id (3, datetime.date(2015, 7, 10))
# id (3, datetime.date(2015, 7, 11))
# id (3, datetime.date(2015, 7, 12))
# id (3, datetime.date(2015, 7, 14))
# id (3, datetime.date(2015, 7, 15))
# id (3, datetime.date(2015, 7, 16))
# id (3, datetime.date(2015, 7, 17))
# id (3, datetime.date(2015, 7, 18))
# id (3, datetime.date(2015, 7, 19))
# id (3, datetime.date(2015, 7, 21))
# id (3, datetime.date(2015, 7, 22))
# id (3, datetime.date(2015, 7, 23))
# id (3, datetime.date(2015, 7, 24))
# id (3, datetime.date(2015, 7, 25))
# id (3, datetime.date(2015, 7, 26))
# id (3, datetime.date(2015, 7, 28))
# id (3, datetime.date(2015, 7, 29))
# id (3, datetime.date(2015, 7, 30))
# id (3, datetime.date(2015, 7, 31))
# id (3, datetime.date(2015, 8, 1))
# id (3, datetime.date(2015, 8, 2))
# id (3, datetime.date(2015, 8, 5))
# id (3, datetime.date(2015, 8, 6))
# id (3, datetime.date(2015, 8, 7))
# id (3, datetime.date(2015, 8, 8))
# id (3, datetime.date(2015, 8, 9))
# id (3, datetime.date(2015, 8, 10))
# id (3, datetime.date(2015, 8, 12))
# id (3, datetime.date(2015, 8, 13))
# id (3, datetime.date(2015, 8, 14))
# id (3, datetime.date(2015, 8, 15))
# id (3, datetime.date(2015, 8, 16))
# id (3, datetime.date(2015, 8, 17))
# id (3, datetime.date(2015, 8, 19))
# id (3, datetime.date(2015, 8, 20))
# id (3, datetime.date(2015, 8, 21))
# id (3, datetime.date(2015, 8, 22))
# id (3, datetime.date(2015, 8, 23))
# id (3, datetime.date(2015, 8, 24))
# id (3, datetime.date(2015, 8, 26))
# id (3, datetime.date(2015, 8, 27))
# id (3, datetime.date(2015, 8, 28))
# id (3, datetime.date(2015, 8, 29))
# id (3, datetime.date(2015, 8, 30))
# id (3, datetime.date(2015, 9, 1))
# id (3, datetime.date(2015, 9, 2))
# id (3, datetime.date(2015, 9, 3))
# id (3, datetime.date(2015, 9, 4))
# id (3, datetime.date(2015, 9, 5))
# id (3, datetime.date(2015, 9, 6))
# id (3, datetime.date(2015, 9, 8))
# id (3, datetime.date(2015, 9, 9))
# id (3, datetime.date(2015, 9, 10))
# id (3, datetime.date(2015, 9, 11))
# id (3, datetime.date(2015, 9, 12))
# id (3, datetime.date(2015, 9, 14))
# id (3, datetime.date(2015, 9, 15))
# id (3, datetime.date(2015, 9, 16))
# id (3, datetime.date(2015, 9, 17))
# id (3, datetime.date(2015, 9, 18))
# id (3, datetime.date(2015, 9, 19))
# id (3, datetime.date(2015, 9, 21))
# id (3, datetime.date(2015, 9, 22))
# id (3, datetime.date(2015, 9, 23))
# id (3, datetime.date(2015, 9, 24))
# id (3, datetime.date(2015, 9, 25))
# id (3, datetime.date(2015, 9, 26))
# id (3, datetime.date(2015, 9, 28))
# id (3, datetime.date(2015, 9, 29))
# id (3, datetime.date(2015, 9, 30))
# id (3, datetime.date(2015, 10, 1))
# id (3, datetime.date(2015, 10, 2))
# id (3, datetime.date(2015, 10, 4))
# id (3, datetime.date(2015, 10, 5))
# id (3, datetime.date(2015, 10, 6))
# id (3, datetime.date(2015, 10, 7))
# id (3, datetime.date(2015, 10, 8))
# id (3, datetime.date(2015, 10, 9))
# id (3, datetime.date(2015, 10, 11))
# id (3, datetime.date(2015, 10, 12))
# id (3, datetime.date(2015, 10, 13))
# id (3, datetime.date(2015, 10, 14))
# id (3, datetime.date(2015, 10, 15))
# id (3, datetime.date(2015, 10, 16))
# id (3, datetime.date(2015, 10, 18))
# id (3, datetime.date(2015, 10, 19))
# id (3, datetime.date(2015, 10, 20))
# id (3, datetime.date(2015, 10, 21))
# id (3, datetime.date(2015, 10, 22))
# id (3, datetime.date(2015, 10, 24))
# id (3, datetime.date(2015, 10, 25))
# id (3, datetime.date(2015, 10, 26))
# id (3, datetime.date(2015, 10, 27))
# id (3, datetime.date(2015, 10, 28))
# id (3, datetime.date(2015, 10, 29))
# id (3, datetime.date(2015, 10, 31))
# id (3, datetime.date(2015, 11, 1))
# id (3, datetime.date(2015, 11, 2))
# id (3, datetime.date(2015, 11, 4))
# id (3, datetime.date(2015, 11, 5))
# id (3, datetime.date(2015, 11, 6))
# id (3, datetime.date(2015, 11, 7))
# id (3, datetime.date(2015, 11, 8))
# id (3, datetime.date(2015, 11, 9))
# id (3, datetime.date(2015, 11, 11))
# id (3, datetime.date(2015, 11, 12))
# id (3, datetime.date(2015, 11, 13))
# id (3, datetime.date(2015, 11, 14))
# id (3, datetime.date(2015, 11, 16))
# id (3, datetime.date(2015, 11, 17))
# id (3, datetime.date(2015, 11, 18))
# id (3, datetime.date(2015, 11, 19))
# id (3, datetime.date(2015, 11, 20))
# id (3, datetime.date(2015, 11, 21))
# id (3, datetime.date(2015, 11, 23))
# id (3, datetime.date(2015, 11, 24))
# id (3, datetime.date(2015, 11, 25))
# id (3, datetime.date(2015, 11, 26))
# id (3, datetime.date(2015, 11, 28))
# id (3, datetime.date(2015, 11, 29))
# id (3, datetime.date(2015, 11, 30))
# id (3, datetime.date(2015, 12, 1))
# id (3, datetime.date(2015, 12, 2))
# id (3, datetime.date(2015, 12, 3))
# id (3, datetime.date(2015, 12, 5))
# id (3, datetime.date(2015, 12, 6))
# id (3, datetime.date(2015, 12, 7))
# id (3, datetime.date(2015, 12, 8))
# id (3, datetime.date(2015, 12, 9))
# id (3, datetime.date(2015, 12, 10))
# id (3, datetime.date(2015, 12, 12))
# id (3, datetime.date(2015, 12, 13))
# id (3, datetime.date(2015, 12, 14))
# id (3, datetime.date(2015, 12, 15))
# id (3, datetime.date(2015, 12, 16))
# id (3, datetime.date(2015, 12, 17))
# id (3, datetime.date(2015, 12, 19))
# id (3, datetime.date(2015, 12, 20))
# id (3, datetime.date(2015, 12, 21))
# id (3, datetime.date(2015, 12, 22))
# id (3, datetime.date(2015, 12, 24))
# id (3, datetime.date(2015, 12, 25))
# id (3, datetime.date(2015, 12, 26))
# id (3, datetime.date(2015, 12, 27))
# id (3, datetime.date(2015, 12, 28))
# id (3, datetime.date(2015, 12, 29))
# id (3, datetime.date(2015, 12, 31))
# id (3, datetime.date(2016, 1, 2))
# id (3, datetime.date(2016, 1, 3))
# id (3, datetime.date(2016, 1, 4))
# id (3, datetime.date(2016, 1, 5))
# id (3, datetime.date(2016, 1, 7))
# id (3, datetime.date(2016, 1, 8))
# id (3, datetime.date(2016, 1, 9))
# id (3, datetime.date(2016, 1, 10))
# id (3, datetime.date(2016, 1, 11))
# id (3, datetime.date(2016, 1, 12))
# id (3, datetime.date(2016, 1, 14))
# id (3, datetime.date(2016, 1, 15))
# id (3, datetime.date(2016, 1, 16))
# id (3, datetime.date(2016, 1, 17))
# id (3, datetime.date(2016, 1, 18))
# id (3, datetime.date(2016, 1, 19))
# id (3, datetime.date(2016, 1, 21))
# id (3, datetime.date(2016, 1, 22))
# id (3, datetime.date(2016, 1, 23))
# id (3, datetime.date(2016, 1, 26))
# id (3, datetime.date(2016, 1, 27))
# id (3, datetime.date(2016, 1, 28))
# id (3, datetime.date(2016, 1, 29))
# id (3, datetime.date(2016, 1, 30))
# id (3, datetime.date(2016, 2, 2))
# id (3, datetime.date(2016, 2, 3))
# id (5, datetime.date(2014, 12, 16))
# id (5, datetime.date(2014, 12, 17))
# id (5, datetime.date(2014, 12, 23))
# id (5, datetime.date(2014, 12, 24))
# id (5, datetime.date(2015, 4, 28))
# id (5, datetime.date(2015, 4, 30))
# id (5, datetime.date(2015, 5, 1))
# id (5, datetime.date(2015, 5, 2))
# id (5, datetime.date(2015, 5, 3))
# id (5, datetime.date(2015, 5, 5))
# id (5, datetime.date(2015, 5, 6))
# id (5, datetime.date(2015, 5, 7))
# id (5, datetime.date(2015, 5, 8))
# id (5, datetime.date(2015, 5, 9))
# id (5, datetime.date(2015, 5, 10))
# id (5, datetime.date(2015, 5, 12))
# id (5, datetime.date(2015, 5, 13))
# id (5, datetime.date(2015, 5, 15))
# id (5, datetime.date(2015, 5, 16))
# id (5, datetime.date(2015, 5, 17))
# id (5, datetime.date(2015, 5, 18))
# id (5, datetime.date(2015, 5, 19))
# id (5, datetime.date(2015, 5, 20))
# id (5, datetime.date(2015, 5, 22))
# id (5, datetime.date(2015, 5, 23))
# id (5, datetime.date(2015, 5, 24))
# id (5, datetime.date(2015, 5, 25))
# id (5, datetime.date(2015, 5, 26))
# id (5, datetime.date(2015, 5, 27))
# id (5, datetime.date(2015, 5, 29))
# id (5, datetime.date(2015, 5, 30))
# id (5, datetime.date(2015, 5, 31))
# id (5, datetime.date(2015, 6, 1))
# id (5, datetime.date(2015, 6, 2))
# id (5, datetime.date(2015, 6, 3))
# id (5, datetime.date(2015, 6, 5))
# id (5, datetime.date(2015, 6, 6))
# id (5, datetime.date(2015, 6, 7))
# id (5, datetime.date(2015, 6, 8))
# id (5, datetime.date(2015, 6, 9))
# id (5, datetime.date(2015, 6, 10))
# id (5, datetime.date(2015, 6, 12))
# id (5, datetime.date(2015, 6, 13))
# id (5, datetime.date(2015, 6, 14))
# id (5, datetime.date(2015, 6, 15))
# id (5, datetime.date(2015, 6, 17))
# id (5, datetime.date(2015, 6, 18))
# id (5, datetime.date(2015, 6, 20))
# id (5, datetime.date(2015, 6, 21))
# id (5, datetime.date(2015, 6, 22))
# id (5, datetime.date(2015, 6, 24))
# id (5, datetime.date(2015, 6, 25))
# id (5, datetime.date(2015, 6, 26))
# id (5, datetime.date(2015, 6, 27))
# id (5, datetime.date(2015, 6, 28))
# id (5, datetime.date(2015, 6, 29))
# id (5, datetime.date(2015, 7, 1))
# id (5, datetime.date(2015, 7, 2))
# id (5, datetime.date(2015, 7, 4))
# id (5, datetime.date(2015, 7, 5))
# id (5, datetime.date(2015, 7, 6))
# id (5, datetime.date(2015, 7, 7))
# id (5, datetime.date(2015, 7, 8))
# id (5, datetime.date(2015, 7, 9))
# id (5, datetime.date(2015, 7, 11))
# id (5, datetime.date(2015, 7, 12))
# id (5, datetime.date(2015, 7, 13))
# id (5, datetime.date(2015, 7, 14))
# id (5, datetime.date(2015, 7, 15))
# id (5, datetime.date(2015, 7, 16))
# id (5, datetime.date(2015, 7, 18))
# id (5, datetime.date(2015, 7, 19))
# id (5, datetime.date(2015, 7, 20))
# id (5, datetime.date(2015, 7, 21))
# id (5, datetime.date(2015, 7, 22))
# id (5, datetime.date(2015, 7, 23))
# id (5, datetime.date(2015, 7, 27))
# id (5, datetime.date(2015, 7, 28))
# id (5, datetime.date(2015, 7, 29))
# id (5, datetime.date(2015, 7, 30))
# id (5, datetime.date(2015, 7, 31))
# id (5, datetime.date(2015, 8, 1))
# id (5, datetime.date(2015, 8, 3))
# id (5, datetime.date(2015, 8, 4))
# id (5, datetime.date(2015, 8, 5))
# id (5, datetime.date(2015, 8, 6))
# id (5, datetime.date(2015, 8, 7))
# id (5, datetime.date(2015, 8, 8))
# id (5, datetime.date(2015, 8, 10))
# id (5, datetime.date(2015, 8, 11))
# id (5, datetime.date(2015, 8, 12))
# id (5, datetime.date(2015, 8, 13))
# id (5, datetime.date(2015, 8, 14))
# id (5, datetime.date(2015, 8, 15))
# id (5, datetime.date(2015, 8, 17))
# id (5, datetime.date(2015, 8, 18))
# id (5, datetime.date(2015, 8, 19))
# id (5, datetime.date(2015, 8, 20))
# id (5, datetime.date(2015, 8, 21))
# id (5, datetime.date(2015, 8, 22))
# id (5, datetime.date(2015, 8, 24))
# id (5, datetime.date(2015, 8, 25))
# id (5, datetime.date(2015, 8, 26))
# id (5, datetime.date(2015, 8, 27))
# id (5, datetime.date(2015, 8, 28))
# id (5, datetime.date(2015, 8, 29))
# id (5, datetime.date(2015, 8, 31))
# id (5, datetime.date(2015, 9, 1))
# id (5, datetime.date(2015, 9, 2))
# id (5, datetime.date(2015, 9, 3))
# id (5, datetime.date(2015, 9, 4))
# id (5, datetime.date(2015, 9, 5))
# id (5, datetime.date(2015, 9, 7))
# id (5, datetime.date(2015, 9, 10))
# id (5, datetime.date(2015, 9, 11))
# id (5, datetime.date(2015, 9, 12))
# id (5, datetime.date(2015, 9, 13))
# id (5, datetime.date(2015, 9, 14))
# id (5, datetime.date(2015, 9, 15))
# id (5, datetime.date(2015, 9, 17))
# id (5, datetime.date(2015, 9, 27))
# id (5, datetime.date(2015, 9, 28))
# id (5, datetime.date(2015, 9, 29))
# id (5, datetime.date(2015, 9, 30))
# id (5, datetime.date(2015, 10, 31))
# id (5, datetime.date(2015, 11, 1))
# id (5, datetime.date(2015, 11, 2))
# id (5, datetime.date(2015, 11, 3))
# id (5, datetime.date(2015, 11, 4))
# id (5, datetime.date(2015, 11, 5))
# id (5, datetime.date(2015, 11, 7))
# id (5, datetime.date(2015, 11, 8))
# id (5, datetime.date(2015, 11, 9))
# id (5, datetime.date(2015, 11, 10))
# id (5, datetime.date(2015, 11, 11))
# id (5, datetime.date(2015, 11, 12))
# id (5, datetime.date(2015, 11, 14))
# id (5, datetime.date(2015, 11, 15))
# id (5, datetime.date(2015, 11, 16))
# id (5, datetime.date(2015, 11, 17))
# id (5, datetime.date(2015, 11, 18))
# id (5, datetime.date(2015, 11, 19))
# id (5, datetime.date(2015, 11, 22))
# id (5, datetime.date(2015, 11, 23))
# id (5, datetime.date(2015, 11, 24))
# id (5, datetime.date(2015, 11, 25))
# id (5, datetime.date(2015, 11, 26))
# id (5, datetime.date(2015, 11, 27))
# id (5, datetime.date(2015, 11, 29))
# id (5, datetime.date(2015, 11, 30))
# id (5, datetime.date(2015, 12, 1))
# id (5, datetime.date(2015, 12, 3))
# id (7, datetime.date(2015, 1, 7))
# id (7, datetime.date(2015, 1, 8))
# id (7, datetime.date(2015, 1, 12))
# id (7, datetime.date(2015, 1, 13))
# id (7, datetime.date(2015, 1, 14))
# id (7, datetime.date(2015, 5, 23))
# id (7, datetime.date(2015, 5, 24))
# id (7, datetime.date(2015, 5, 25))
# id (7, datetime.date(2015, 5, 26))
# id (7, datetime.date(2015, 5, 27))
# id (7, datetime.date(2015, 5, 28))
# id (7, datetime.date(2015, 5, 30))
# id (7, datetime.date(2015, 5, 31))
# id (7, datetime.date(2015, 6, 2))
# id (7, datetime.date(2015, 6, 3))
# id (7, datetime.date(2015, 6, 4))
# id (7, datetime.date(2015, 6, 5))
# id (7, datetime.date(2015, 6, 7))
# id (7, datetime.date(2015, 6, 8))
# id (7, datetime.date(2015, 6, 9))
# id (7, datetime.date(2015, 6, 11))
# id (7, datetime.date(2015, 6, 12))
# id (7, datetime.date(2015, 6, 13))
# id (7, datetime.date(2015, 6, 14))
# id (7, datetime.date(2015, 6, 15))
# id (7, datetime.date(2015, 6, 16))
# id (7, datetime.date(2015, 6, 18))
# id (7, datetime.date(2015, 6, 19))
# id (7, datetime.date(2015, 6, 20))
# id (7, datetime.date(2015, 6, 22))
# id (7, datetime.date(2015, 6, 23))
# id (7, datetime.date(2015, 6, 25))
# id (7, datetime.date(2015, 6, 26))
# id (7, datetime.date(2015, 6, 27))
# id (7, datetime.date(2015, 6, 29))
# id (7, datetime.date(2015, 6, 30))
# id (7, datetime.date(2015, 7, 2))
# id (7, datetime.date(2015, 7, 3))
# id (7, datetime.date(2015, 7, 4))
# id (7, datetime.date(2015, 7, 5))
# id (7, datetime.date(2015, 7, 6))
# id (7, datetime.date(2015, 7, 7))
# id (7, datetime.date(2015, 7, 9))
# id (7, datetime.date(2015, 7, 10))
# id (7, datetime.date(2015, 7, 14))
# id (7, datetime.date(2015, 7, 16))
# id (7, datetime.date(2015, 7, 17))
# id (7, datetime.date(2015, 7, 18))
# id (7, datetime.date(2015, 7, 19))
# id (7, datetime.date(2015, 7, 21))
# id (7, datetime.date(2015, 7, 22))
# id (7, datetime.date(2015, 7, 23))
# id (7, datetime.date(2015, 7, 24))
# id (7, datetime.date(2015, 7, 25))
# id (7, datetime.date(2015, 7, 26))
# id (7, datetime.date(2015, 7, 28))
# id (7, datetime.date(2015, 7, 29))
# id (7, datetime.date(2015, 7, 31))
# id (7, datetime.date(2015, 8, 1))
# id (7, datetime.date(2015, 8, 2))
# id (7, datetime.date(2015, 8, 4))
# id (7, datetime.date(2015, 8, 5))
# id (7, datetime.date(2015, 8, 6))
# id (7, datetime.date(2015, 8, 7))
# id (7, datetime.date(2015, 8, 8))
# id (7, datetime.date(2015, 8, 9))
# id (7, datetime.date(2015, 8, 11))
# id (7, datetime.date(2015, 8, 12))
# id (7, datetime.date(2015, 8, 13))
# id (7, datetime.date(2015, 8, 14))
# id (7, datetime.date(2015, 8, 16))
# id (7, datetime.date(2015, 8, 18))
# id (7, datetime.date(2015, 8, 19))
# id (7, datetime.date(2015, 8, 20))
# id (7, datetime.date(2015, 8, 21))
# id (7, datetime.date(2015, 8, 22))
# id (7, datetime.date(2015, 8, 25))
# id (7, datetime.date(2015, 8, 28))
# id (7, datetime.date(2015, 8, 29))
# id (7, datetime.date(2015, 8, 30))
# id (7, datetime.date(2015, 9, 1))
# id (7, datetime.date(2015, 9, 2))
# id (7, datetime.date(2015, 9, 3))
# id (7, datetime.date(2015, 9, 4))
# id (7, datetime.date(2015, 9, 5))
# id (7, datetime.date(2015, 9, 6))
# id (7, datetime.date(2015, 9, 8))
# id (7, datetime.date(2015, 9, 9))
# id (7, datetime.date(2015, 9, 10))
# id (7, datetime.date(2015, 9, 11))
# id (7, datetime.date(2015, 9, 12))
# id (7, datetime.date(2015, 9, 13))
# id (7, datetime.date(2015, 9, 15))
# id (7, datetime.date(2015, 9, 16))
# id (7, datetime.date(2015, 9, 17))
# id (7, datetime.date(2015, 9, 18))
# id (7, datetime.date(2015, 9, 19))
# id (7, datetime.date(2015, 9, 20))
# id (7, datetime.date(2015, 9, 22))
# id (7, datetime.date(2015, 9, 23))
# id (7, datetime.date(2015, 9, 24))
# id (7, datetime.date(2015, 9, 25))
# id (7, datetime.date(2015, 9, 29))
# id (7, datetime.date(2015, 9, 30))
# id (7, datetime.date(2015, 10, 1))
# id (7, datetime.date(2015, 10, 2))
# id (7, datetime.date(2015, 10, 4))
# id (7, datetime.date(2015, 10, 6))
# id (7, datetime.date(2015, 10, 7))
# id (7, datetime.date(2015, 10, 8))
# id (7, datetime.date(2015, 10, 9))
# id (7, datetime.date(2015, 10, 10))
# id (7, datetime.date(2015, 10, 11))
# id (7, datetime.date(2015, 10, 15))
# id (7, datetime.date(2015, 10, 16))
# id (7, datetime.date(2015, 10, 18))
# id (7, datetime.date(2015, 10, 20))
# id (7, datetime.date(2015, 10, 21))
# id (7, datetime.date(2015, 10, 22))
# id (7, datetime.date(2015, 10, 23))
# id (7, datetime.date(2015, 10, 24))
# id (7, datetime.date(2015, 10, 25))
# id (7, datetime.date(2015, 10, 27))
# id (7, datetime.date(2015, 10, 28))
# id (7, datetime.date(2015, 10, 29))
# id (7, datetime.date(2015, 10, 30))
# id (7, datetime.date(2015, 10, 31))
# id (7, datetime.date(2015, 11, 1))
# id (7, datetime.date(2015, 11, 3))
# id (7, datetime.date(2015, 11, 4))
# id (7, datetime.date(2015, 11, 5))
# id (7, datetime.date(2015, 11, 6))
# id (7, datetime.date(2015, 11, 7))
# id (7, datetime.date(2015, 11, 8))
# id (7, datetime.date(2015, 11, 10))
# id (7, datetime.date(2015, 11, 11))
# id (7, datetime.date(2015, 11, 12))
# id (7, datetime.date(2015, 11, 13))
# id (7, datetime.date(2015, 11, 14))
# id (7, datetime.date(2015, 11, 15))
# id (7, datetime.date(2015, 11, 17))
# id (7, datetime.date(2015, 11, 18))
# id (7, datetime.date(2015, 11, 19))
# id (7, datetime.date(2015, 11, 20))
# id (7, datetime.date(2015, 11, 21))
# id (7, datetime.date(2015, 11, 22))
# id (7, datetime.date(2015, 11, 24))
# id (7, datetime.date(2015, 11, 25))
# id (7, datetime.date(2015, 11, 26))
# id (7, datetime.date(2015, 11, 27))
# id (7, datetime.date(2015, 11, 29))
# id (7, datetime.date(2015, 11, 30))
# id (7, datetime.date(2015, 12, 1))
# id (7, datetime.date(2015, 12, 2))
# id (7, datetime.date(2015, 12, 3))
# id (7, datetime.date(2015, 12, 4))
# id (7, datetime.date(2015, 12, 6))
# id (7, datetime.date(2015, 12, 7))
# id (7, datetime.date(2015, 12, 8))
# id (7, datetime.date(2015, 12, 9))
# id (7, datetime.date(2015, 12, 11))
# id (7, datetime.date(2015, 12, 13))
# id (7, datetime.date(2015, 12, 14))
# id (7, datetime.date(2015, 12, 15))
# id (7, datetime.date(2015, 12, 17))
# id (7, datetime.date(2015, 12, 18))
# id (7, datetime.date(2015, 12, 20))
# id (7, datetime.date(2015, 12, 21))
# id (7, datetime.date(2015, 12, 23))
# id (7, datetime.date(2015, 12, 24))
# id (7, datetime.date(2015, 12, 27))
# id (7, datetime.date(2015, 12, 29))
# id (7, datetime.date(2016, 1, 1))
# id (7, datetime.date(2016, 1, 2))
# id (7, datetime.date(2016, 1, 4))
# id (7, datetime.date(2016, 1, 5))
# id (7, datetime.date(2016, 1, 6))
# id (7, datetime.date(2016, 1, 8))
# id (7, datetime.date(2016, 1, 9))
# id (7, datetime.date(2016, 1, 11))
# id (7, datetime.date(2016, 1, 14))
# id (7, datetime.date(2016, 1, 16))
# id (7, datetime.date(2016, 1, 17))
# id (7, datetime.date(2016, 1, 18))
# id (7, datetime.date(2016, 1, 20))
# id (7, datetime.date(2016, 1, 22))
# id (7, datetime.date(2016, 1, 23))
# id (7, datetime.date(2016, 1, 24))
# id (7, datetime.date(2016, 1, 25))
# id (7, datetime.date(2016, 2, 4))
# id (7, datetime.date(2016, 2, 5))
# id (7, datetime.date(2016, 2, 6))
# id (7, datetime.date(2016, 2, 8))
# id (7, datetime.date(2016, 2, 11))
# id (7, datetime.date(2016, 2, 13))
# id (7, datetime.date(2016, 2, 15))
# id (7, datetime.date(2016, 2, 17))
# id (7, datetime.date(2016, 2, 18))
# id (8, datetime.date(2015, 5, 24))
# id (8, datetime.date(2015, 5, 26))
# id (8, datetime.date(2015, 5, 27))
# id (8, datetime.date(2015, 5, 31))
# id (8, datetime.date(2015, 6, 2))
# id (8, datetime.date(2015, 6, 3))
# id (8, datetime.date(2015, 6, 5))
# id (8, datetime.date(2015, 6, 6))
# id (8, datetime.date(2015, 6, 14))
# id (8, datetime.date(2015, 6, 15))
# id (8, datetime.date(2015, 6, 16))
# id (8, datetime.date(2015, 6, 17))
# id (8, datetime.date(2015, 6, 20))
# id (8, datetime.date(2015, 6, 21))
# id (8, datetime.date(2015, 6, 22))
# id (8, datetime.date(2015, 6, 23))
# id (8, datetime.date(2015, 6, 24))
# id (8, datetime.date(2015, 6, 25))
# id (8, datetime.date(2015, 6, 28))
# id (8, datetime.date(2015, 6, 29))
# id (8, datetime.date(2015, 7, 1))
# id (8, datetime.date(2015, 7, 2))
# id (8, datetime.date(2015, 7, 3))
# id (8, datetime.date(2015, 7, 7))
# id (8, datetime.date(2015, 7, 8))
# id (8, datetime.date(2015, 7, 10))
# id (8, datetime.date(2015, 7, 13))
# id (8, datetime.date(2015, 7, 14))
# id (8, datetime.date(2015, 7, 15))
# id (8, datetime.date(2015, 7, 17))
# id (8, datetime.date(2015, 7, 18))
# id (8, datetime.date(2015, 7, 20))
# id (8, datetime.date(2015, 7, 24))
# id (8, datetime.date(2015, 7, 25))
# id (8, datetime.date(2015, 7, 30))
# id (8, datetime.date(2015, 7, 31))
# id (8, datetime.date(2015, 8, 5))
# id (8, datetime.date(2015, 8, 6))
# id (8, datetime.date(2015, 8, 7))
# id (8, datetime.date(2015, 8, 10))
# id (8, datetime.date(2015, 8, 11))
# id (8, datetime.date(2015, 8, 12))
# id (8, datetime.date(2015, 8, 13))
# id (8, datetime.date(2015, 8, 15))
# id (8, datetime.date(2015, 8, 17))
# id (8, datetime.date(2015, 8, 20))
# id (8, datetime.date(2015, 8, 21))
# id (8, datetime.date(2015, 8, 24))
# id (8, datetime.date(2015, 8, 27))
# id (8, datetime.date(2015, 8, 28))
# id (8, datetime.date(2015, 8, 29))
# id (8, datetime.date(2015, 9, 1))
# id (8, datetime.date(2015, 9, 3))
# id (8, datetime.date(2015, 9, 7))
# id (8, datetime.date(2015, 9, 8))
# id (8, datetime.date(2015, 9, 11))
# id (8, datetime.date(2015, 9, 14))
# id (8, datetime.date(2015, 9, 18))
# id (8, datetime.date(2015, 9, 20))
# id (8, datetime.date(2015, 9, 23))
# id (8, datetime.date(2015, 9, 26))
# id (8, datetime.date(2015, 9, 28))
# id (8, datetime.date(2015, 9, 30))
# id (8, datetime.date(2015, 10, 1))
# id (8, datetime.date(2015, 10, 2))
# id (8, datetime.date(2015, 10, 6))
# id (8, datetime.date(2015, 10, 8))
# id (8, datetime.date(2015, 10, 11))
# id (8, datetime.date(2015, 10, 13))
# id (8, datetime.date(2015, 10, 14))
# id (8, datetime.date(2015, 10, 15))
# id (8, datetime.date(2015, 10, 17))
# id (8, datetime.date(2015, 10, 19))
# id (8, datetime.date(2015, 10, 23))
# id (8, datetime.date(2015, 10, 24))
# id (8, datetime.date(2015, 10, 26))
# id (8, datetime.date(2015, 10, 27))
# id (8, datetime.date(2015, 10, 28))
# id (8, datetime.date(2015, 10, 30))
# id (8, datetime.date(2015, 10, 31))
# id (8, datetime.date(2015, 11, 1))
# id (8, datetime.date(2015, 11, 2))
# id (8, datetime.date(2015, 11, 4))
# id (8, datetime.date(2015, 11, 7))
# id (8, datetime.date(2015, 11, 9))
# id (8, datetime.date(2015, 11, 14))
# id (8, datetime.date(2015, 11, 16))
# id (8, datetime.date(2015, 11, 17))
# id (8, datetime.date(2015, 11, 20))
# id (8, datetime.date(2015, 11, 21))
# id (8, datetime.date(2015, 11, 22))
# id (8, datetime.date(2015, 11, 23))
# id (8, datetime.date(2015, 11, 25))
# id (8, datetime.date(2015, 11, 26))
# id (8, datetime.date(2015, 11, 28))
# id (9, datetime.date(2015, 5, 23))
# id (9, datetime.date(2015, 5, 24))
# id (9, datetime.date(2015, 5, 25))
# id (9, datetime.date(2015, 5, 26))
# id (9, datetime.date(2015, 5, 27))
# id (9, datetime.date(2015, 5, 28))
# id (9, datetime.date(2015, 5, 30))
# id (9, datetime.date(2015, 5, 31))
# id (9, datetime.date(2015, 6, 1))
# id (9, datetime.date(2015, 6, 2))
# id (9, datetime.date(2015, 6, 3))
# id (9, datetime.date(2015, 6, 4))
# id (9, datetime.date(2015, 6, 6))
# id (9, datetime.date(2015, 6, 7))
# id (9, datetime.date(2015, 6, 8))
# id (9, datetime.date(2015, 6, 9))
# id (9, datetime.date(2015, 6, 11))
# id (9, datetime.date(2015, 6, 12))
# id (9, datetime.date(2015, 6, 13))
# id (9, datetime.date(2015, 6, 14))
# id (9, datetime.date(2015, 6, 15))
# id (9, datetime.date(2015, 6, 16))
# id (9, datetime.date(2015, 6, 18))
# id (9, datetime.date(2015, 6, 19))
# id (9, datetime.date(2015, 6, 20))
# id (9, datetime.date(2015, 6, 21))
# id (9, datetime.date(2015, 6, 22))
# id (9, datetime.date(2015, 6, 23))
# id (9, datetime.date(2015, 6, 25))
# id (9, datetime.date(2015, 6, 26))
# id (9, datetime.date(2015, 6, 27))
# id (9, datetime.date(2015, 6, 28))
# id (9, datetime.date(2015, 6, 30))
# id (9, datetime.date(2015, 7, 2))
# id (9, datetime.date(2015, 7, 3))
# id (9, datetime.date(2015, 7, 4))
# id (9, datetime.date(2015, 7, 5))
# id (9, datetime.date(2015, 7, 6))
# id (9, datetime.date(2015, 7, 7))
# id (9, datetime.date(2015, 7, 9))
# id (9, datetime.date(2015, 7, 10))
# id (9, datetime.date(2015, 7, 11))
# id (9, datetime.date(2015, 7, 12))
# id (9, datetime.date(2015, 7, 13))
# id (9, datetime.date(2015, 7, 14))
# id (9, datetime.date(2015, 7, 16))
# id (9, datetime.date(2015, 7, 17))
# id (9, datetime.date(2015, 7, 20))
# id (9, datetime.date(2015, 7, 21))
# id (9, datetime.date(2015, 7, 22))
# id (9, datetime.date(2015, 7, 23))
# id (9, datetime.date(2015, 7, 24))
# id (9, datetime.date(2015, 7, 25))
# id (9, datetime.date(2015, 7, 27))
# id (9, datetime.date(2015, 7, 28))
# id (9, datetime.date(2015, 7, 29))
# id (9, datetime.date(2015, 7, 30))
# id (9, datetime.date(2015, 7, 31))
# id (9, datetime.date(2015, 8, 1))
# id (9, datetime.date(2015, 8, 3))
# id (9, datetime.date(2015, 8, 4))
# id (9, datetime.date(2015, 8, 5))
# id (9, datetime.date(2015, 8, 6))
# id (9, datetime.date(2015, 8, 7))
# id (9, datetime.date(2015, 8, 8))
# id (9, datetime.date(2015, 8, 10))
# id (9, datetime.date(2015, 8, 11))
# id (9, datetime.date(2015, 8, 12))
# id (9, datetime.date(2015, 8, 13))
# id (9, datetime.date(2015, 8, 14))
# id (9, datetime.date(2015, 8, 16))
# id (9, datetime.date(2015, 8, 17))
# id (9, datetime.date(2015, 8, 18))
# id (9, datetime.date(2015, 8, 19))
# id (9, datetime.date(2015, 8, 20))
# id (9, datetime.date(2015, 8, 22))
# id (9, datetime.date(2015, 8, 23))
# id (9, datetime.date(2015, 8, 24))
# id (9, datetime.date(2015, 8, 25))
# id (9, datetime.date(2015, 8, 26))
# id (9, datetime.date(2015, 8, 27))
# id (9, datetime.date(2015, 8, 29))
# id (9, datetime.date(2015, 8, 30))
# id (9, datetime.date(2015, 8, 31))
# id (9, datetime.date(2015, 9, 1))
# id (9, datetime.date(2015, 9, 2))
# id (9, datetime.date(2015, 9, 3))
# id (9, datetime.date(2015, 9, 5))
# id (9, datetime.date(2015, 9, 6))
# id (9, datetime.date(2015, 9, 7))
# id (9, datetime.date(2015, 9, 9))
# id (9, datetime.date(2015, 9, 10))
# id (9, datetime.date(2015, 9, 11))
# id (9, datetime.date(2015, 9, 12))
# id (9, datetime.date(2015, 9, 13))
# id (9, datetime.date(2015, 9, 14))
# id (9, datetime.date(2015, 9, 16))
# id (9, datetime.date(2015, 9, 17))
# id (9, datetime.date(2015, 9, 18))
# id (9, datetime.date(2015, 9, 19))
# id (9, datetime.date(2015, 9, 20))
# id (9, datetime.date(2015, 9, 21))
# id (9, datetime.date(2015, 9, 23))
# id (9, datetime.date(2015, 9, 24))
# id (9, datetime.date(2015, 9, 25))
# id (9, datetime.date(2015, 9, 26))
# id (9, datetime.date(2015, 9, 27))
# id (9, datetime.date(2015, 9, 29))
# id (9, datetime.date(2015, 9, 30))
# id (9, datetime.date(2015, 10, 1))
# id (9, datetime.date(2015, 10, 2))
# id (9, datetime.date(2015, 10, 3))
# id (9, datetime.date(2015, 10, 4))
# id (9, datetime.date(2015, 10, 6))
# id (9, datetime.date(2015, 10, 7))
# id (9, datetime.date(2015, 10, 8))
# id (9, datetime.date(2015, 10, 9))
# id (9, datetime.date(2015, 10, 10))
# id (9, datetime.date(2015, 10, 11))
# id (9, datetime.date(2015, 10, 13))
# id (9, datetime.date(2015, 10, 14))
# id (9, datetime.date(2015, 10, 15))
# id (9, datetime.date(2015, 10, 16))
# id (9, datetime.date(2015, 10, 17))
# id (9, datetime.date(2015, 10, 18))
# id (9, datetime.date(2015, 10, 20))
# id (9, datetime.date(2015, 10, 21))
# id (9, datetime.date(2015, 10, 22))
# id (9, datetime.date(2015, 10, 23))
# id (9, datetime.date(2015, 10, 25))
# id (9, datetime.date(2015, 10, 26))
# id (9, datetime.date(2015, 10, 27))
# id (9, datetime.date(2015, 10, 29))
# id (9, datetime.date(2015, 10, 30))
# id (9, datetime.date(2015, 10, 31))
# id (9, datetime.date(2015, 11, 1))
# id (9, datetime.date(2015, 11, 2))
# id (9, datetime.date(2015, 11, 3))
# id (9, datetime.date(2015, 11, 5))
# id (9, datetime.date(2015, 11, 6))
# id (9, datetime.date(2015, 11, 7))
# id (9, datetime.date(2015, 11, 8))
# id (9, datetime.date(2015, 11, 9))
# id (9, datetime.date(2015, 11, 10))
# id (9, datetime.date(2015, 11, 13))
# id (9, datetime.date(2015, 11, 14))
# id (9, datetime.date(2015, 11, 15))
# id (9, datetime.date(2015, 11, 16))
# id (9, datetime.date(2015, 11, 17))
# id (9, datetime.date(2015, 11, 18))
# id (9, datetime.date(2015, 11, 20))
# id (9, datetime.date(2015, 11, 21))
# id (9, datetime.date(2015, 11, 22))
# id (9, datetime.date(2015, 11, 23))
# id (9, datetime.date(2015, 11, 25))
# id (9, datetime.date(2015, 11, 26))
# id (9, datetime.date(2015, 11, 27))
# id (9, datetime.date(2015, 11, 28))
# id (9, datetime.date(2015, 11, 29))
# id (9, datetime.date(2015, 11, 30))
# id (9, datetime.date(2015, 12, 3))
# id (9, datetime.date(2015, 12, 4))
# id (9, datetime.date(2015, 12, 6))
# id (9, datetime.date(2015, 12, 7))
# id (9, datetime.date(2015, 12, 9))
# id (9, datetime.date(2015, 12, 10))
# id (9, datetime.date(2015, 12, 11))
# id (9, datetime.date(2015, 12, 12))
# id (9, datetime.date(2015, 12, 13))
# id (9, datetime.date(2015, 12, 14))
# id (9, datetime.date(2015, 12, 16))
# id (9, datetime.date(2015, 12, 17))
# id (9, datetime.date(2015, 12, 18))
# id (9, datetime.date(2015, 12, 19))
# id (9, datetime.date(2015, 12, 20))
# id (9, datetime.date(2015, 12, 21))
# id (9, datetime.date(2015, 12, 23))
# id (9, datetime.date(2015, 12, 24))
# id (9, datetime.date(2015, 12, 25))
# id (9, datetime.date(2015, 12, 27))
# id (9, datetime.date(2015, 12, 28))
# id (9, datetime.date(2015, 12, 30))
# id (9, datetime.date(2015, 12, 31))
# id (9, datetime.date(2016, 1, 1))
# id (9, datetime.date(2016, 1, 2))
# id (9, datetime.date(2016, 1, 3))
# id (9, datetime.date(2016, 1, 4))
# id (9, datetime.date(2016, 1, 6))
# id (9, datetime.date(2016, 1, 7))
# id (9, datetime.date(2016, 1, 8))
# id (9, datetime.date(2016, 1, 9))
# id (9, datetime.date(2016, 1, 12))
# id (9, datetime.date(2016, 1, 13))
# id (9, datetime.date(2016, 1, 14))
# id (9, datetime.date(2016, 1, 15))
# id (9, datetime.date(2016, 1, 16))
# id (9, datetime.date(2016, 1, 17))
# id (9, datetime.date(2016, 1, 20))
# id (9, datetime.date(2016, 1, 21))
# id (9, datetime.date(2016, 1, 22))
# id (9, datetime.date(2016, 1, 24))
# id (9, datetime.date(2016, 1, 26))
# id (9, datetime.date(2016, 1, 27))
# id (9, datetime.date(2016, 1, 28))
# id (9, datetime.date(2016, 1, 29))
# id (9, datetime.date(2016, 1, 30))
# id (10, datetime.date(2015, 4, 22))
# id (10, datetime.date(2015, 4, 23))
# id (10, datetime.date(2015, 4, 24))
# id (10, datetime.date(2015, 4, 26))
# id (10, datetime.date(2015, 4, 27))
# id (10, datetime.date(2015, 4, 30))
# id (10, datetime.date(2015, 5, 1))
# id (10, datetime.date(2015, 5, 4))
# id (10, datetime.date(2015, 5, 5))
# id (10, datetime.date(2015, 5, 6))
# id (10, datetime.date(2015, 5, 7))
# id (10, datetime.date(2015, 5, 10))
# id (10, datetime.date(2015, 5, 11))
# id (10, datetime.date(2015, 5, 12))
# id (10, datetime.date(2015, 5, 13))
# id (10, datetime.date(2015, 5, 14))
# id (10, datetime.date(2015, 5, 15))
# id (10, datetime.date(2015, 5, 20))
# id (10, datetime.date(2015, 5, 21))
# id (10, datetime.date(2015, 5, 23))
# id (10, datetime.date(2015, 5, 24))
# id (10, datetime.date(2015, 5, 25))
# id (10, datetime.date(2015, 5, 26))
# id (10, datetime.date(2015, 5, 27))
# id (10, datetime.date(2015, 5, 28))
# id (10, datetime.date(2015, 5, 30))
# id (10, datetime.date(2015, 6, 1))
# id (10, datetime.date(2015, 6, 2))
# id (10, datetime.date(2015, 6, 3))
# id (10, datetime.date(2015, 6, 4))
# id (10, datetime.date(2015, 6, 5))
# id (10, datetime.date(2015, 6, 6))
# id (10, datetime.date(2015, 6, 7))
# id (10, datetime.date(2015, 6, 8))
# id (10, datetime.date(2015, 6, 9))
# id (10, datetime.date(2015, 6, 10))
# id (10, datetime.date(2015, 6, 11))
# id (10, datetime.date(2015, 6, 13))
# id (10, datetime.date(2015, 6, 14))
# id (10, datetime.date(2015, 6, 15))
# id (10, datetime.date(2015, 6, 17))
# id (10, datetime.date(2015, 6, 18))
# id (10, datetime.date(2015, 6, 20))
# id (10, datetime.date(2015, 6, 21))
# id (10, datetime.date(2015, 6, 22))
# id (10, datetime.date(2015, 6, 23))
# id (10, datetime.date(2015, 6, 24))
# id (10, datetime.date(2015, 6, 25))
# id (10, datetime.date(2015, 6, 27))
# id (10, datetime.date(2015, 6, 28))
# id (10, datetime.date(2015, 6, 29))
# id (10, datetime.date(2015, 6, 30))
# id (10, datetime.date(2015, 7, 1))
# id (10, datetime.date(2015, 7, 2))
# id (10, datetime.date(2015, 7, 5))
# id (10, datetime.date(2015, 7, 6))
# id (10, datetime.date(2015, 7, 7))
# id (10, datetime.date(2015, 7, 8))
# id (10, datetime.date(2015, 7, 9))
# id (10, datetime.date(2015, 7, 10))
# id (10, datetime.date(2015, 7, 12))
# id (10, datetime.date(2015, 7, 13))
# id (10, datetime.date(2015, 7, 14))
# id (10, datetime.date(2015, 7, 15))
# id (10, datetime.date(2015, 7, 16))
# id (10, datetime.date(2015, 7, 17))
# id (10, datetime.date(2015, 7, 18))
# id (10, datetime.date(2015, 7, 19))
# id (10, datetime.date(2015, 7, 20))
# id (10, datetime.date(2015, 7, 21))
# id (10, datetime.date(2015, 7, 23))
# id (10, datetime.date(2015, 7, 24))
# id (10, datetime.date(2015, 7, 25))
# id (10, datetime.date(2015, 7, 26))
# id (10, datetime.date(2015, 7, 27))
# id (10, datetime.date(2015, 7, 28))
# id (10, datetime.date(2015, 7, 30))
# id (10, datetime.date(2015, 7, 31))
# id (10, datetime.date(2015, 8, 2))
# id (10, datetime.date(2015, 8, 3))
# id (10, datetime.date(2015, 8, 4))
# id (10, datetime.date(2015, 8, 6))
# id (10, datetime.date(2015, 8, 7))
# id (10, datetime.date(2015, 8, 8))
# id (10, datetime.date(2015, 8, 9))
# id (10, datetime.date(2015, 8, 10))
# id (10, datetime.date(2015, 8, 11))
# id (10, datetime.date(2015, 8, 13))
# id (10, datetime.date(2015, 8, 14))
# id (10, datetime.date(2015, 8, 15))
# id (10, datetime.date(2015, 8, 16))
# id (10, datetime.date(2015, 8, 17))
# id (10, datetime.date(2015, 8, 18))
# id (10, datetime.date(2015, 8, 21))
# id (10, datetime.date(2015, 8, 22))
# id (10, datetime.date(2015, 8, 23))
# id (10, datetime.date(2015, 8, 24))
# id (10, datetime.date(2015, 8, 25))
# id (10, datetime.date(2015, 8, 26))
# id (10, datetime.date(2015, 8, 28))
# id (10, datetime.date(2015, 8, 29))
# id (10, datetime.date(2015, 8, 31))
# id (10, datetime.date(2015, 9, 1))
# id (10, datetime.date(2015, 9, 2))
# id (10, datetime.date(2015, 9, 5))
# id (10, datetime.date(2015, 9, 6))
# id (10, datetime.date(2015, 9, 7))
# id (10, datetime.date(2015, 9, 8))
# id (10, datetime.date(2015, 9, 9))
# id (10, datetime.date(2015, 9, 11))
# id (10, datetime.date(2015, 9, 12))
# id (10, datetime.date(2015, 9, 13))
# id (10, datetime.date(2015, 9, 14))
# id (10, datetime.date(2015, 9, 15))
# id (10, datetime.date(2015, 9, 17))
# id (10, datetime.date(2015, 9, 24))
# id (10, datetime.date(2015, 9, 25))
# id (10, datetime.date(2015, 9, 26))
# id (10, datetime.date(2015, 9, 27))
# id (10, datetime.date(2015, 9, 28))
# id (10, datetime.date(2015, 10, 1))
# id (10, datetime.date(2015, 10, 2))
# id (10, datetime.date(2015, 10, 3))
# id (10, datetime.date(2015, 10, 4))
# id (10, datetime.date(2015, 10, 5))
# id (10, datetime.date(2015, 10, 6))
# id (10, datetime.date(2015, 10, 8))
# id (10, datetime.date(2015, 10, 9))
# id (10, datetime.date(2015, 10, 10))
# id (10, datetime.date(2015, 10, 12))
# id (10, datetime.date(2015, 10, 13))
# id (10, datetime.date(2015, 10, 15))
# id (10, datetime.date(2015, 10, 16))
# id (10, datetime.date(2015, 10, 17))
# id (10, datetime.date(2015, 10, 18))
# id (10, datetime.date(2015, 10, 19))
# id (10, datetime.date(2015, 10, 20))
# id (10, datetime.date(2015, 10, 22))
# id (10, datetime.date(2015, 10, 25))
# id (10, datetime.date(2015, 10, 26))
# id (10, datetime.date(2015, 10, 27))
# id (10, datetime.date(2015, 10, 28))
# id (10, datetime.date(2015, 10, 29))
# id (10, datetime.date(2015, 10, 30))
# id (10, datetime.date(2015, 11, 1))
# id (10, datetime.date(2015, 11, 2))
# id (10, datetime.date(2015, 11, 4))
# id (10, datetime.date(2015, 11, 5))
# id (10, datetime.date(2015, 11, 6))
# id (10, datetime.date(2015, 11, 8))
# id (10, datetime.date(2015, 11, 9))
# id (10, datetime.date(2015, 11, 10))
# id (10, datetime.date(2015, 11, 11))
# id (10, datetime.date(2015, 11, 12))
# id (10, datetime.date(2015, 11, 13))
# id (10, datetime.date(2015, 11, 15))
# id (10, datetime.date(2015, 11, 16))
# id (10, datetime.date(2015, 11, 25))
# id (10, datetime.date(2015, 11, 27))
# id (10, datetime.date(2015, 11, 28))
# id (10, datetime.date(2015, 11, 29))
# id (10, datetime.date(2015, 11, 30))
# id (10, datetime.date(2015, 12, 1))
# id (10, datetime.date(2015, 12, 2))
# id (10, datetime.date(2015, 12, 4))
# id (10, datetime.date(2015, 12, 5))
# id (10, datetime.date(2015, 12, 6))
# id (10, datetime.date(2015, 12, 7))
# id (10, datetime.date(2015, 12, 8))
# id (10, datetime.date(2015, 12, 9))
# id (10, datetime.date(2015, 12, 11))
# id (10, datetime.date(2015, 12, 13))
# id (10, datetime.date(2015, 12, 14))
# id (10, datetime.date(2015, 12, 15))
# id (10, datetime.date(2015, 12, 16))
# id (10, datetime.date(2015, 12, 18))
# id (10, datetime.date(2015, 12, 19))
# id (10, datetime.date(2015, 12, 20))
# id (10, datetime.date(2015, 12, 21))
# id (10, datetime.date(2015, 12, 22))
# id (10, datetime.date(2015, 12, 23))
# id (11, datetime.date(2015, 4, 24))
# id (11, datetime.date(2015, 4, 25))
# id (11, datetime.date(2015, 4, 26))
# id (11, datetime.date(2015, 4, 27))
# id (11, datetime.date(2015, 5, 3))
# id (11, datetime.date(2015, 5, 4))
# id (11, datetime.date(2015, 5, 12))
# id (11, datetime.date(2015, 5, 23))
# id (11, datetime.date(2015, 5, 26))
# id (11, datetime.date(2015, 5, 29))
# id (11, datetime.date(2015, 5, 30))
# id (11, datetime.date(2015, 6, 1))
# id (11, datetime.date(2015, 6, 2))
# id (11, datetime.date(2015, 6, 6))
# id (11, datetime.date(2015, 6, 8))
# id (11, datetime.date(2015, 6, 11))
# id (11, datetime.date(2015, 6, 12))
# id (11, datetime.date(2015, 6, 13))
# id (11, datetime.date(2015, 6, 14))
# id (11, datetime.date(2015, 6, 15))
# id (11, datetime.date(2015, 6, 20))
# id (11, datetime.date(2015, 6, 22))
# id (11, datetime.date(2015, 6, 26))
# id (11, datetime.date(2015, 7, 1))
# id (11, datetime.date(2015, 7, 9))
# id (11, datetime.date(2015, 7, 10))
# id (11, datetime.date(2015, 7, 11))
# id (11, datetime.date(2015, 7, 13))
# id (11, datetime.date(2015, 7, 19))
# id (11, datetime.date(2015, 7, 25))
# id (11, datetime.date(2015, 7, 26))
# id (11, datetime.date(2015, 8, 5))
# id (11, datetime.date(2015, 8, 7))
# id (11, datetime.date(2015, 8, 8))
# id (11, datetime.date(2015, 8, 9))
# id (11, datetime.date(2015, 8, 11))
# id (11, datetime.date(2015, 8, 15))
# id (11, datetime.date(2015, 8, 16))
# id (11, datetime.date(2015, 8, 18))
# id (11, datetime.date(2015, 8, 19))
# id (11, datetime.date(2015, 8, 22))
# id (11, datetime.date(2015, 8, 28))
# id (11, datetime.date(2015, 8, 29))
# id (11, datetime.date(2015, 9, 2))
# id (11, datetime.date(2015, 9, 6))
# id (11, datetime.date(2015, 9, 9))
# id (11, datetime.date(2015, 9, 12))
# id (11, datetime.date(2015, 9, 13))
# id (11, datetime.date(2015, 9, 14))
# id (11, datetime.date(2015, 9, 20))
# id (11, datetime.date(2015, 9, 26))
# id (11, datetime.date(2015, 10, 1))
# id (11, datetime.date(2015, 10, 2))
# id (11, datetime.date(2015, 10, 7))
# id (11, datetime.date(2015, 10, 8))
# id (11, datetime.date(2015, 10, 9))
# id (11, datetime.date(2015, 10, 10))
# id (11, datetime.date(2015, 10, 19))
# id (11, datetime.date(2015, 10, 27))
# id (11, datetime.date(2015, 10, 31))
# id (11, datetime.date(2015, 11, 1))
# id (11, datetime.date(2015, 11, 2))
# id (11, datetime.date(2015, 11, 7))
# id (11, datetime.date(2015, 11, 9))
# id (11, datetime.date(2015, 11, 15))
# id (11, datetime.date(2015, 11, 16))
# id (11, datetime.date(2015, 11, 17))
# id (11, datetime.date(2015, 11, 20))
# id (11, datetime.date(2015, 12, 2))
# id (11, datetime.date(2015, 12, 15))
# id (14, datetime.date(2015, 5, 23))
# id (14, datetime.date(2015, 5, 24))
# id (14, datetime.date(2015, 5, 25))
# id (14, datetime.date(2015, 5, 26))
# id (14, datetime.date(2015, 5, 27))
# id (14, datetime.date(2015, 5, 28))
# id (14, datetime.date(2015, 5, 30))
# id (14, datetime.date(2015, 5, 31))
# id (14, datetime.date(2015, 6, 1))
# id (14, datetime.date(2015, 6, 2))
# id (14, datetime.date(2015, 6, 3))
# id (14, datetime.date(2015, 6, 4))
# id (14, datetime.date(2015, 6, 6))
# id (14, datetime.date(2015, 6, 7))
# id (14, datetime.date(2015, 6, 9))
# id (14, datetime.date(2015, 6, 10))
# id (14, datetime.date(2015, 6, 11))
# id (14, datetime.date(2015, 6, 13))
# id (14, datetime.date(2015, 6, 14))
# id (14, datetime.date(2015, 6, 15))
# id (14, datetime.date(2015, 6, 16))
# id (14, datetime.date(2015, 6, 17))
# id (14, datetime.date(2015, 6, 18))
# id (14, datetime.date(2015, 6, 20))
# id (14, datetime.date(2015, 6, 21))
# id (14, datetime.date(2015, 6, 22))
# id (14, datetime.date(2015, 6, 23))
# id (14, datetime.date(2015, 6, 24))
# id (14, datetime.date(2015, 6, 25))
# id (14, datetime.date(2015, 6, 27))
# id (14, datetime.date(2015, 6, 28))
# id (14, datetime.date(2015, 6, 29))
# id (14, datetime.date(2015, 6, 30))
# id (14, datetime.date(2015, 7, 1))
# id (14, datetime.date(2015, 7, 2))
# id (14, datetime.date(2015, 7, 4))
# id (14, datetime.date(2015, 7, 5))
# id (14, datetime.date(2015, 7, 6))
# id (14, datetime.date(2015, 7, 7))
# id (14, datetime.date(2015, 7, 8))
# id (14, datetime.date(2015, 7, 9))
# id (14, datetime.date(2015, 7, 11))
# id (14, datetime.date(2015, 7, 12))
# id (14, datetime.date(2015, 7, 13))
# id (14, datetime.date(2015, 7, 14))
# id (14, datetime.date(2015, 7, 15))
# id (14, datetime.date(2015, 7, 16))
# id (14, datetime.date(2015, 7, 18))
# id (14, datetime.date(2015, 7, 19))
# id (14, datetime.date(2015, 7, 20))
# id (14, datetime.date(2015, 7, 21))
# id (14, datetime.date(2015, 7, 22))
# id (14, datetime.date(2015, 7, 23))
# id (14, datetime.date(2015, 7, 25))
# ...
# id (290, datetime.date(2015, 12, 21))
# id (290, datetime.date(2015, 12, 22))
# id (290, datetime.date(2015, 12, 23))
# id (290, datetime.date(2015, 12, 24))
# id (290, datetime.date(2015, 12, 25))
# id (290, datetime.date(2015, 12, 28))
# id (290, datetime.date(2015, 12, 29))
# id (290, datetime.date(2015, 12, 30))
# id (290, datetime.date(2015, 12, 31))
# id (291, datetime.date(2015, 5, 23))
# id (291, datetime.date(2015, 5, 26))
# id (291, datetime.date(2015, 5, 28))
# id (291, datetime.date(2015, 5, 31))
# id (291, datetime.date(2015, 6, 1))
# id (291, datetime.date(2015, 6, 2))
# id (291, datetime.date(2015, 6, 4))
# id (291, datetime.date(2015, 6, 6))
# id (291, datetime.date(2015, 6, 8))
# id (291, datetime.date(2015, 6, 10))
# id (291, datetime.date(2015, 6, 11))
# id (291, datetime.date(2015, 6, 13))
# id (291, datetime.date(2015, 6, 15))
# id (291, datetime.date(2015, 6, 16))
# id (291, datetime.date(2015, 6, 18))
# id (291, datetime.date(2015, 6, 21))
# id (291, datetime.date(2015, 6, 22))
# id (291, datetime.date(2015, 6, 23))
# id (291, datetime.date(2015, 6, 24))
# id (291, datetime.date(2015, 6, 25))
# id (291, datetime.date(2015, 6, 27))
# id (291, datetime.date(2015, 6, 28))
# id (291, datetime.date(2015, 6, 29))
# id (291, datetime.date(2015, 6, 30))
# id (291, datetime.date(2015, 7, 5))
# id (291, datetime.date(2015, 7, 6))
# id (291, datetime.date(2015, 7, 7))
# id (291, datetime.date(2015, 7, 8))
# id (291, datetime.date(2015, 7, 9))
# id (291, datetime.date(2015, 7, 11))
# id (291, datetime.date(2015, 7, 12))
# id (291, datetime.date(2015, 7, 13))
# id (291, datetime.date(2015, 7, 14))
# id (291, datetime.date(2015, 7, 15))
# id (291, datetime.date(2015, 7, 16))
# id (291, datetime.date(2015, 7, 19))
# id (291, datetime.date(2015, 7, 20))
# id (291, datetime.date(2015, 7, 21))
# id (291, datetime.date(2015, 7, 22))
# id (291, datetime.date(2015, 7, 23))
# id (291, datetime.date(2015, 7, 25))
# id (291, datetime.date(2015, 7, 26))
# id (291, datetime.date(2015, 7, 27))
# id (291, datetime.date(2015, 7, 28))
# id (291, datetime.date(2015, 7, 29))
# id (291, datetime.date(2015, 7, 30))
# id (291, datetime.date(2015, 8, 1))
# id (291, datetime.date(2015, 8, 3))
# id (291, datetime.date(2015, 8, 4))
# id (291, datetime.date(2015, 8, 5))
# id (291, datetime.date(2015, 8, 8))
# id (291, datetime.date(2015, 8, 10))
# id (291, datetime.date(2015, 8, 11))
# id (291, datetime.date(2015, 8, 12))
# id (291, datetime.date(2015, 8, 13))
# id (291, datetime.date(2015, 8, 15))
# id (291, datetime.date(2015, 8, 16))
# id (291, datetime.date(2015, 8, 17))
# id (291, datetime.date(2015, 8, 18))
# id (291, datetime.date(2015, 8, 19))
# id (291, datetime.date(2015, 8, 20))
# id (291, datetime.date(2015, 8, 22))
# id (291, datetime.date(2015, 8, 24))
# id (291, datetime.date(2015, 8, 25))
# id (291, datetime.date(2015, 8, 26))
# id (291, datetime.date(2015, 8, 27))
# id (291, datetime.date(2015, 8, 29))
# id (291, datetime.date(2015, 8, 30))
# id (291, datetime.date(2015, 8, 31))
# id (291, datetime.date(2015, 9, 1))
# id (291, datetime.date(2015, 9, 2))
# id (291, datetime.date(2015, 9, 3))
# id (291, datetime.date(2015, 9, 5))
# id (291, datetime.date(2015, 9, 7))
# id (291, datetime.date(2015, 9, 8))
# id (291, datetime.date(2015, 9, 9))
# id (291, datetime.date(2015, 9, 10))
# id (291, datetime.date(2015, 9, 12))
# id (291, datetime.date(2015, 9, 13))
# id (291, datetime.date(2015, 9, 14))
# id (291, datetime.date(2015, 9, 15))
# id (291, datetime.date(2015, 9, 19))
# id (291, datetime.date(2015, 9, 20))
# id (291, datetime.date(2015, 9, 21))
# id (291, datetime.date(2015, 9, 22))
# id (291, datetime.date(2015, 9, 23))
# id (291, datetime.date(2015, 9, 24))
# id (291, datetime.date(2015, 9, 26))
# id (291, datetime.date(2015, 9, 27))
# id (291, datetime.date(2015, 9, 29))
# id (291, datetime.date(2015, 9, 30))
# id (291, datetime.date(2015, 10, 1))
# id (291, datetime.date(2015, 10, 4))
# id (291, datetime.date(2015, 10, 5))
# id (291, datetime.date(2015, 10, 6))
# id (291, datetime.date(2015, 10, 7))
# id (291, datetime.date(2015, 10, 8))
# id (291, datetime.date(2015, 10, 12))
# id (291, datetime.date(2015, 10, 13))
# id (291, datetime.date(2015, 10, 14))
# id (291, datetime.date(2015, 10, 15))
# id (291, datetime.date(2015, 10, 16))
# id (291, datetime.date(2015, 10, 17))
# id (291, datetime.date(2015, 10, 19))
# id (291, datetime.date(2015, 10, 20))
# id (291, datetime.date(2015, 10, 21))
# id (291, datetime.date(2015, 10, 22))
# id (291, datetime.date(2015, 10, 23))
# id (291, datetime.date(2015, 10, 24))
# id (291, datetime.date(2015, 10, 26))
# id (291, datetime.date(2015, 10, 27))
# id (291, datetime.date(2015, 10, 28))
# id (291, datetime.date(2015, 10, 29))
# id (291, datetime.date(2015, 10, 30))
# id (291, datetime.date(2015, 10, 31))
# id (291, datetime.date(2015, 11, 2))
# id (291, datetime.date(2015, 11, 3))
# id (291, datetime.date(2015, 11, 19))
# id (291, datetime.date(2015, 11, 20))
# id (291, datetime.date(2015, 11, 22))
# id (291, datetime.date(2015, 11, 23))
# id (291, datetime.date(2015, 11, 24))
# id (291, datetime.date(2015, 11, 25))
# id (291, datetime.date(2015, 11, 26))
# id (291, datetime.date(2015, 11, 30))
# id (291, datetime.date(2015, 12, 1))
# id (291, datetime.date(2015, 12, 2))
# id (291, datetime.date(2015, 12, 3))
# id (291, datetime.date(2015, 12, 4))
# id (291, datetime.date(2015, 12, 6))
# id (291, datetime.date(2015, 12, 7))
# id (291, datetime.date(2015, 12, 21))
# id (291, datetime.date(2015, 12, 22))
# id (291, datetime.date(2015, 12, 23))
# id (291, datetime.date(2015, 12, 24))
# id (291, datetime.date(2015, 12, 25))
# id (291, datetime.date(2015, 12, 27))
# id (291, datetime.date(2015, 12, 28))
# id (291, datetime.date(2015, 12, 29))
# id (291, datetime.date(2015, 12, 30))
# id (291, datetime.date(2015, 12, 31))
# id (291, datetime.date(2016, 1, 3))
# id (291, datetime.date(2016, 1, 4))
# id (291, datetime.date(2016, 1, 5))
# id (291, datetime.date(2016, 1, 6))
# id (291, datetime.date(2016, 1, 7))
# id (291, datetime.date(2016, 1, 8))
# id (291, datetime.date(2016, 1, 10))
# id (291, datetime.date(2016, 1, 11))
# id (291, datetime.date(2016, 1, 12))
# id (291, datetime.date(2016, 1, 13))
# id (291, datetime.date(2016, 1, 14))
# id (291, datetime.date(2016, 1, 15))
# id (291, datetime.date(2016, 1, 17))
# id (291, datetime.date(2016, 1, 18))
# id (291, datetime.date(2016, 1, 19))
# id (291, datetime.date(2016, 1, 20))
# id (291, datetime.date(2016, 1, 21))
# id (291, datetime.date(2016, 1, 24))
# id (291, datetime.date(2016, 1, 25))
# id (291, datetime.date(2016, 1, 26))
# id (291, datetime.date(2016, 1, 27))
# id (291, datetime.date(2016, 1, 28))
# id (291, datetime.date(2016, 1, 29))
# id (291, datetime.date(2016, 1, 31))
# id (291, datetime.date(2016, 2, 1))
# id (291, datetime.date(2016, 2, 2))
# id (291, datetime.date(2016, 2, 3))
# id (291, datetime.date(2016, 2, 4))
# id (292, datetime.date(2014, 5, 23))
# id (292, datetime.date(2014, 5, 24))
# id (292, datetime.date(2014, 5, 25))
# id (292, datetime.date(2014, 5, 26))
# id (292, datetime.date(2014, 5, 27))
# id (292, datetime.date(2014, 5, 28))
# id (292, datetime.date(2015, 3, 14))
# id (292, datetime.date(2015, 3, 15))
# id (292, datetime.date(2015, 3, 16))
# id (292, datetime.date(2015, 4, 22))
# id (292, datetime.date(2015, 4, 25))
# id (292, datetime.date(2015, 4, 26))
# id (292, datetime.date(2015, 4, 28))
# id (292, datetime.date(2015, 5, 2))
# id (292, datetime.date(2015, 5, 5))
# id (292, datetime.date(2015, 5, 9))
# id (292, datetime.date(2015, 5, 11))
# id (292, datetime.date(2015, 5, 12))
# id (292, datetime.date(2015, 5, 14))
# id (292, datetime.date(2015, 5, 15))
# id (292, datetime.date(2015, 5, 19))
# id (292, datetime.date(2015, 5, 31))
# id (292, datetime.date(2015, 6, 3))
# id (292, datetime.date(2015, 6, 5))
# id (292, datetime.date(2015, 6, 7))
# id (292, datetime.date(2015, 6, 9))
# id (292, datetime.date(2015, 6, 10))
# id (292, datetime.date(2015, 6, 12))
# id (292, datetime.date(2015, 6, 13))
# id (292, datetime.date(2015, 6, 14))
# id (292, datetime.date(2015, 6, 17))
# id (292, datetime.date(2015, 6, 19))
# id (292, datetime.date(2015, 6, 20))
# id (292, datetime.date(2015, 6, 21))
# id (292, datetime.date(2015, 6, 24))
# id (292, datetime.date(2015, 6, 25))
# id (292, datetime.date(2015, 6, 28))
# id (292, datetime.date(2015, 6, 30))
# id (292, datetime.date(2015, 7, 1))
# id (292, datetime.date(2015, 7, 2))
# id (292, datetime.date(2015, 7, 3))
# id (292, datetime.date(2015, 7, 5))
# id (292, datetime.date(2015, 7, 7))
# id (292, datetime.date(2015, 7, 10))
# id (292, datetime.date(2015, 7, 14))
# id (292, datetime.date(2015, 7, 15))
# id (292, datetime.date(2015, 7, 16))
# id (292, datetime.date(2015, 7, 17))
# id (292, datetime.date(2015, 7, 19))
# id (292, datetime.date(2015, 7, 28))
# id (292, datetime.date(2015, 7, 29))
# id (292, datetime.date(2015, 7, 31))
# id (292, datetime.date(2015, 8, 5))
# id (292, datetime.date(2015, 8, 6))
# id (292, datetime.date(2015, 8, 7))
# id (292, datetime.date(2015, 8, 9))
# id (292, datetime.date(2015, 8, 17))
# id (292, datetime.date(2015, 8, 20))
# id (292, datetime.date(2015, 8, 23))
# id (292, datetime.date(2015, 8, 24))
# id (292, datetime.date(2015, 8, 27))
# id (292, datetime.date(2015, 8, 28))
# id (292, datetime.date(2015, 9, 4))
# id (292, datetime.date(2015, 9, 6))
# id (292, datetime.date(2015, 9, 11))
# id (292, datetime.date(2015, 9, 13))
# id (292, datetime.date(2015, 9, 21))
# id (292, datetime.date(2015, 9, 22))
# id (292, datetime.date(2015, 9, 30))
# id (292, datetime.date(2015, 10, 1))
# id (292, datetime.date(2015, 10, 2))
# id (292, datetime.date(2015, 10, 8))
# id (292, datetime.date(2015, 10, 9))
# id (292, datetime.date(2015, 10, 12))
# id (292, datetime.date(2015, 10, 15))
# id (292, datetime.date(2015, 10, 16))
# id (292, datetime.date(2015, 10, 17))
# id (292, datetime.date(2015, 10, 19))
# id (292, datetime.date(2015, 10, 20))
# id (292, datetime.date(2015, 10, 24))
# id (292, datetime.date(2015, 10, 25))
# id (292, datetime.date(2015, 10, 26))
# id (292, datetime.date(2015, 10, 30))
# id (292, datetime.date(2015, 10, 31))
# id (292, datetime.date(2015, 11, 1))
# id (292, datetime.date(2015, 11, 2))
# id (292, datetime.date(2015, 11, 6))
# id (292, datetime.date(2015, 11, 14))
# id (292, datetime.date(2015, 11, 16))
# id (292, datetime.date(2015, 11, 20))
# id (292, datetime.date(2015, 11, 23))
# id (292, datetime.date(2015, 11, 27))
# id (293, datetime.date(2015, 4, 22))
# id (293, datetime.date(2015, 4, 23))
# id (293, datetime.date(2015, 4, 24))
# id (293, datetime.date(2015, 4, 26))
# id (293, datetime.date(2015, 4, 27))
# id (293, datetime.date(2015, 4, 28))
# id (293, datetime.date(2015, 4, 29))
# id (293, datetime.date(2015, 4, 30))
# id (293, datetime.date(2015, 5, 1))
# id (293, datetime.date(2015, 5, 3))
# id (293, datetime.date(2015, 5, 4))
# id (293, datetime.date(2015, 5, 5))
# id (293, datetime.date(2015, 5, 6))
# id (293, datetime.date(2015, 5, 7))
# id (293, datetime.date(2015, 5, 8))
# id (293, datetime.date(2015, 5, 10))
# id (293, datetime.date(2015, 5, 11))
# id (293, datetime.date(2015, 5, 12))
# id (293, datetime.date(2015, 5, 13))
# id (293, datetime.date(2015, 5, 14))
# id (293, datetime.date(2015, 5, 17))
# id (293, datetime.date(2015, 5, 18))
# id (293, datetime.date(2015, 5, 19))
# id (293, datetime.date(2015, 5, 20))
# id (293, datetime.date(2015, 5, 21))
# id (293, datetime.date(2015, 5, 23))
# id (293, datetime.date(2015, 5, 25))
# id (293, datetime.date(2015, 5, 26))
# id (293, datetime.date(2015, 5, 27))
# id (293, datetime.date(2015, 5, 28))
# id (293, datetime.date(2015, 5, 30))
# id (293, datetime.date(2015, 6, 1))
# id (293, datetime.date(2015, 6, 2))
# id (293, datetime.date(2015, 6, 3))
# id (293, datetime.date(2015, 6, 6))
# id (293, datetime.date(2015, 6, 7))
# id (293, datetime.date(2015, 6, 9))
# id (293, datetime.date(2015, 6, 10))
# id (293, datetime.date(2015, 6, 13))
# id (293, datetime.date(2015, 6, 14))
# id (293, datetime.date(2015, 6, 17))
# id (293, datetime.date(2015, 6, 18))
# id (293, datetime.date(2015, 6, 20))
# id (293, datetime.date(2015, 6, 22))
# id (293, datetime.date(2015, 6, 23))
# id (293, datetime.date(2015, 6, 24))
# id (293, datetime.date(2015, 6, 25))
# id (293, datetime.date(2015, 6, 29))
# id (293, datetime.date(2015, 6, 30))
# id (293, datetime.date(2015, 7, 1))
# id (293, datetime.date(2015, 7, 2))
# id (293, datetime.date(2015, 7, 4))
# id (293, datetime.date(2015, 7, 5))
# id (293, datetime.date(2015, 7, 6))
# id (293, datetime.date(2015, 7, 7))
# id (293, datetime.date(2015, 7, 8))
# id (293, datetime.date(2015, 7, 9))
# id (293, datetime.date(2015, 7, 11))
# id (293, datetime.date(2015, 7, 12))
# id (293, datetime.date(2015, 7, 13))
# id (293, datetime.date(2015, 7, 14))
# id (293, datetime.date(2015, 7, 15))
# id (293, datetime.date(2015, 7, 16))
# id (293, datetime.date(2015, 7, 18))
# id (293, datetime.date(2015, 7, 20))
# id (293, datetime.date(2015, 7, 25))
# id (293, datetime.date(2015, 7, 26))
# id (293, datetime.date(2015, 7, 27))
# id (293, datetime.date(2015, 7, 28))
# id (293, datetime.date(2015, 7, 29))
# id (293, datetime.date(2015, 7, 30))
# id (293, datetime.date(2015, 8, 3))
# id (293, datetime.date(2015, 8, 4))
# id (293, datetime.date(2015, 8, 5))
# id (293, datetime.date(2015, 8, 6))
# id (293, datetime.date(2015, 8, 8))
# id (293, datetime.date(2015, 8, 10))
# id (293, datetime.date(2015, 8, 11))
# id (293, datetime.date(2015, 8, 13))
# id (293, datetime.date(2015, 8, 16))
# id (293, datetime.date(2015, 8, 17))
# id (293, datetime.date(2015, 8, 18))
# id (293, datetime.date(2015, 8, 20))
# id (293, datetime.date(2015, 8, 21))
# id (293, datetime.date(2015, 8, 23))
# id (293, datetime.date(2015, 8, 24))
# id (293, datetime.date(2015, 8, 25))
# id (293, datetime.date(2015, 8, 26))
# id (293, datetime.date(2015, 8, 27))
# id (293, datetime.date(2015, 8, 28))
# id (293, datetime.date(2015, 8, 30))
# id (293, datetime.date(2015, 8, 31))
# id (293, datetime.date(2015, 9, 1))
# id (293, datetime.date(2015, 9, 2))
# id (293, datetime.date(2015, 9, 3))
# id (293, datetime.date(2015, 9, 4))
# id (293, datetime.date(2015, 9, 7))
# id (293, datetime.date(2015, 9, 8))
# id (293, datetime.date(2015, 9, 9))
# id (293, datetime.date(2015, 9, 10))
# id (293, datetime.date(2015, 9, 11))
# id (293, datetime.date(2015, 9, 12))
# id (293, datetime.date(2015, 9, 15))
# id (293, datetime.date(2015, 9, 16))
# id (293, datetime.date(2015, 9, 17))
# id (293, datetime.date(2015, 9, 18))
# id (293, datetime.date(2015, 9, 19))
# id (293, datetime.date(2015, 9, 20))
# id (293, datetime.date(2015, 9, 22))
# id (293, datetime.date(2015, 9, 23))
# id (293, datetime.date(2015, 9, 24))
# id (293, datetime.date(2015, 9, 25))
# id (293, datetime.date(2015, 9, 26))
# id (293, datetime.date(2015, 9, 27))
# id (293, datetime.date(2015, 9, 29))
# id (293, datetime.date(2015, 10, 1))
# id (293, datetime.date(2015, 10, 2))
# id (293, datetime.date(2015, 10, 3))
# id (293, datetime.date(2015, 10, 4))
# id (293, datetime.date(2015, 10, 5))
# id (293, datetime.date(2015, 10, 6))
# id (293, datetime.date(2015, 10, 8))
# id (293, datetime.date(2015, 10, 9))
# id (293, datetime.date(2015, 10, 10))
# id (293, datetime.date(2015, 10, 11))
# id (293, datetime.date(2015, 10, 12))
# id (293, datetime.date(2015, 10, 13))
# id (293, datetime.date(2015, 10, 15))
# id (293, datetime.date(2015, 10, 17))
# id (293, datetime.date(2015, 10, 18))
# id (293, datetime.date(2015, 10, 19))
# id (293, datetime.date(2015, 10, 20))
# id (293, datetime.date(2015, 10, 22))
# id (293, datetime.date(2015, 10, 23))
# id (293, datetime.date(2015, 10, 24))
# id (293, datetime.date(2015, 10, 26))
# id (293, datetime.date(2015, 10, 27))
# id (293, datetime.date(2015, 10, 30))
# id (293, datetime.date(2015, 10, 31))
# id (293, datetime.date(2015, 11, 1))
# id (293, datetime.date(2015, 11, 2))
# id (293, datetime.date(2015, 11, 3))
# id (293, datetime.date(2015, 11, 5))
# id (293, datetime.date(2015, 11, 6))
# id (293, datetime.date(2015, 11, 7))
# id (293, datetime.date(2015, 11, 8))
# id (293, datetime.date(2015, 11, 9))
# id (293, datetime.date(2015, 11, 10))
# id (293, datetime.date(2015, 11, 13))
# id (293, datetime.date(2015, 11, 14))
# id (293, datetime.date(2015, 11, 15))
# id (293, datetime.date(2015, 11, 16))
# id (293, datetime.date(2015, 11, 17))
# id (293, datetime.date(2015, 11, 18))
# id (293, datetime.date(2015, 11, 20))
# id (293, datetime.date(2015, 11, 21))
# id (293, datetime.date(2015, 11, 22))
# id (293, datetime.date(2015, 11, 24))
# id (293, datetime.date(2015, 11, 25))
# id (293, datetime.date(2015, 11, 27))
# id (293, datetime.date(2015, 11, 28))
# id (293, datetime.date(2015, 11, 29))

# %%
resampled_day.head(500)
# Out:
#                      patient_id corresponding_day  mean_bgl
# time
# 2015-05-23 06:00:00           2        2015-05-23     163.0
# 2015-05-23 06:05:00           2        2015-05-23     159.0
# 2015-05-23 06:10:00           2        2015-05-23     155.0
# 2015-05-23 06:15:00           2        2015-05-23     152.0
# 2015-05-23 06:20:00           2        2015-05-23     147.0
# ...                         ...               ...       ...
# 2015-05-25 11:15:00           2        2015-05-25     174.0
# 2015-05-25 11:20:00           2        2015-05-25     165.0
# 2015-05-25 11:25:00           2        2015-05-25     154.0
# 2015-05-25 11:30:00           2        2015-05-25     143.0
# 2015-05-25 11:35:00           2        2015-05-25     137.0
#
# [500 rows x 3 columns]

# %%
resampled_day.to_csv('resampled_day.csv')

# %%
night_hypo.to_csv('night_hypo.csv')

# %%
resampled_day['mean_bgl'].isna().sum()
# Out:
# 0

# %%
if 'time' not in resampled_day.columns:
    resampled_day.reset_index(inplace=True)

# Extract only the time part from the datetime column to use as new column headers in the pivot table
resampled_day['time_only'] = resampled_day['time'].dt.time

# Pivot the table using 'time_only' as the columns
pivot_df = resampled_day.pivot_table(
    index=['patient_id', 'corresponding_day'],  # Rows: group by 'patient_id' and 'corresponding_day'
    columns='time_only',                        # Columns: only the time part of the day
    values='mean_bgl',                          # Values: 'mean_bgl' to fill the cells
    aggfunc='first'                             # Aggregation function: 'first' just to avoid duplicates
)

# %%
pivot_df.head()
# Out:
# time_only                     06:00:00  06:05:00  06:10:00  06:15:00  \
# patient_id corresponding_day
# 2          2015-05-23            163.0     159.0     155.0     152.0
#            2015-05-24            214.0     215.0     221.0     231.0
#            2015-05-25            115.0     114.0     116.0     118.0
#            2015-05-26            206.0     207.0     207.0     209.0
#            2015-05-27            169.0     171.0     173.0     173.0
#
# time_only                     06:20:00  06:25:00  06:30:00  06:35:00  \
# patient_id corresponding_day
# 2          2015-05-23            147.0    141.00     134.0     126.0
#            2015-05-24            241.0    252.00     266.0     280.0
#            2015-05-25            121.0    122.00     123.0     126.5
#            2015-05-26            211.0    216.75     222.5     229.0
#            2015-05-27            174.0    182.50     177.0     179.0
#
# time_only                     06:40:00  06:45:00  ...  23:10:00  23:15:00  \
# patient_id corresponding_day                      ...
# 2          2015-05-23            121.0     118.0  ...      79.0      81.0
#            2015-05-24            292.0     304.0  ...     232.0     212.0
#            2015-05-25            121.0     122.0  ...     158.0     154.0
#            2015-05-26            239.0     245.0  ...     146.0     144.0
#            2015-05-27            182.0     178.0  ...     118.0     116.0
#
# time_only                     23:20:00  23:25:00  23:30:00  23:35:00  \
# patient_id corresponding_day
# 2          2015-05-23             81.0      82.0      83.0      82.0
#            2015-05-24            193.0     173.0     156.0     132.0
#            2015-05-25            148.0     137.0     127.0     121.0
#            2015-05-26            142.0     141.0     140.0     139.0
#            2015-05-27            113.0     112.0     112.0     113.0
#
# time_only                     23:40:00  23:45:00  23:50:00  23:55:00
# patient_id corresponding_day
# 2          2015-05-23             84.0      85.0      86.0      81.0
#            2015-05-24            116.0     106.0     100.0      95.0
#            2015-05-25            116.0     107.0      99.0      94.0
#            2015-05-26            138.0     137.0     137.0     137.0
#            2015-05-27            116.0     116.0     115.0     114.0
#
# [5 rows x 216 columns]

# %%
night_hypo.head()
# Out:
#    id corresponding_day   hypo
# 0   2        2015-05-23  False
# 1   2        2015-05-24  False
# 2   2        2015-05-25  False
# 3   2        2015-05-26  False
# 4   2        2015-05-27  False

# %%
# Ensure the index of pivot_df is reset to enable merging
pivot_df.reset_index(inplace=True)

# Rename 'patient_id' to 'id' in pivot_df to match the column name in night_hypo for consistency
pivot_df.rename(columns={'patient_id': 'id'}, inplace=True)

# Merge pivot_df with night_hypo
# Assuming night_hypo has columns 'id' and 'corresponding_day' that match with pivot_df
merged_df = pd.merge(pivot_df, night_hypo, on=['id', 'corresponding_day'], how='left')

# Check the merged DataFrame
merged_df.head()
# Out:
#    index  id corresponding_day  06:00:00  06:05:00  06:10:00  06:15:00  \
# 0      0   2        2015-05-23     163.0     159.0     155.0     152.0
# 1      1   2        2015-05-24     214.0     215.0     221.0     231.0
# 2      2   2        2015-05-25     115.0     114.0     116.0     118.0
# 3      3   2        2015-05-26     206.0     207.0     207.0     209.0
# 4      4   2        2015-05-27     169.0     171.0     173.0     173.0
#
#    06:20:00  06:25:00  06:30:00  ...  23:15:00  23:20:00  23:25:00  23:30:00  \
# 0     147.0    141.00     134.0  ...      81.0      81.0      82.0      83.0
# 1     241.0    252.00     266.0  ...     212.0     193.0     173.0     156.0
# 2     121.0    122.00     123.0  ...     154.0     148.0     137.0     127.0
# 3     211.0    216.75     222.5  ...     144.0     142.0     141.0     140.0
# 4     174.0    182.50     177.0  ...     116.0     113.0     112.0     112.0
#
#    23:35:00  23:40:00  23:45:00  23:50:00  23:55:00   hypo
# 0      82.0      84.0      85.0      86.0      81.0  False
# 1     132.0     116.0     106.0     100.0      95.0  False
# 2     121.0     116.0     107.0      99.0      94.0  False
# 3     139.0     138.0     137.0     137.0     137.0  False
# 4     113.0     116.0     116.0     115.0     114.0  False
#
# [5 rows x 220 columns]

# %%
# Drop the 'index' column
merged_df.drop(columns=['index'], inplace=True)

# Set 'id' and 'corresponding_day' as the index
merged_df.set_index(['id', 'corresponding_day'], inplace=True)

# Display the updated DataFrame to check the new indexing
merged_df.head()
# Out:
#                       06:00:00  06:05:00  06:10:00  06:15:00  06:20:00  \
# id corresponding_day
# 2  2015-05-23            163.0     159.0     155.0     152.0     147.0
#    2015-05-24            214.0     215.0     221.0     231.0     241.0
#    2015-05-25            115.0     114.0     116.0     118.0     121.0
#    2015-05-26            206.0     207.0     207.0     209.0     211.0
#    2015-05-27            169.0     171.0     173.0     173.0     174.0
#
#                       06:25:00  06:30:00  06:35:00  06:40:00  06:45:00  ...  \
# id corresponding_day                                                    ...
# 2  2015-05-23           141.00     134.0     126.0     121.0     118.0  ...
#    2015-05-24           252.00     266.0     280.0     292.0     304.0  ...
#    2015-05-25           122.00     123.0     126.5     121.0     122.0  ...
#    2015-05-26           216.75     222.5     229.0     239.0     245.0  ...
#    2015-05-27           182.50     177.0     179.0     182.0     178.0  ...
#
#                       23:15:00  23:20:00  23:25:00  23:30:00  23:35:00  \
# id corresponding_day
# 2  2015-05-23             81.0      81.0      82.0      83.0      82.0
#    2015-05-24            212.0     193.0     173.0     156.0     132.0
#    2015-05-25            154.0     148.0     137.0     127.0     121.0
#    2015-05-26            144.0     142.0     141.0     140.0     139.0
#    2015-05-27            116.0     113.0     112.0     112.0     113.0
#
#                       23:40:00  23:45:00  23:50:00  23:55:00   hypo
# id corresponding_day
# 2  2015-05-23             84.0      85.0      86.0      81.0  False
#    2015-05-24            116.0     106.0     100.0      95.0  False
#    2015-05-25            116.0     107.0      99.0      94.0  False
#    2015-05-26            138.0     137.0     137.0     137.0  False
#    2015-05-27            116.0     116.0     115.0     114.0  False
#
# [5 rows x 217 columns]

# %%
merged_df.to_csv('CGM_RESAMPLED.csv')

# %%
merged_df = pd.merge(pivot_df, night_hypo, on=['id', 'corresponding_day'], how='left')

# %%
unique_ids = cgm['id'].unique()
# Split the unique IDs into training, validation and test sets 80:10:10
train_ids, test_ids = train_test_split(unique_ids, test_size=0.1, random_state=42)
train_ids, validation_ids = train_test_split(train_ids, test_size=0.111, random_state=42)


train_data = merged_df[merged_df['id'].isin(train_ids)]
validation_data = merged_df[merged_df['id'].isin(validation_ids)]
test_data = merged_df[merged_df['id'].isin(test_ids)]

# %%
train_data.to_csv('train_data.csv')
validation_data.to_csv('validation_data.csv')
test_data.to_csv('test_data.csv')
